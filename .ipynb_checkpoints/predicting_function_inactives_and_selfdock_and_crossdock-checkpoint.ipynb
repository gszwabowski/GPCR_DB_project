# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %% [markdown]
# # PREDICTING FUNCTION

# %%
# read data for experimentally determined structures in complex with active molecules
df = pd.read_csv('data/364_interaction_energies_state_function_v4.txt', sep='\t')

#drop index
df.drop('index', axis = 1, inplace=True)

#copy df to structure_df
structure_df = df.copy()
# structure_df.drop(['PDBID','State'], axis = 1, inplace = True)
structure_df.drop(['State'], axis = 1, inplace = True)

# add entry_type field to denote if entry is crystallized, docked, etc.
structure_df['entry_type'] = 'experimentally determined active'

# %%
# read data for best scoring docked poses of inactive molecules
df = pd.read_csv('data/dude_docking_data/dude_interaction_energies.txt', sep='\t')

#drop index
df.drop('index', axis = 1, inplace=True)

#copy df to dock_tructure_df
dock_structure_df = df.copy()
# dock_structure_df.drop(['PDBID','State'], axis = 1, inplace = True)
dock_structure_df.drop(['State'], axis = 1, inplace = True)

# add entry_type field
dock_structure_df['entry_type'] = 'docked inactive'

# %%
# read data for best scoring docked poses of inactive molecules
df1 = pd.read_csv('data/selfdock_docking_data/selfdock_interaction_energies.txt', sep='\t')

#drop index
df1.drop('index', axis = 1, inplace=True)

#copy df to dock_tructure_df
selfdock_structure_df = df1.copy()
# dock_structure_df.drop(['PDBID','State'], axis = 1, inplace = True)
selfdock_structure_df.drop(['State'], axis = 1, inplace = True)

# add entry_type field
selfdock_structure_df['entry_type'] = 'self-docked active'

# %%
# read data for best scoring docked poses of inactive molecules that weren't in the old test set
df2 = pd.read_csv('data/selfdock_docking_data/nontestset_selfdock_interaction_energies.txt', sep='\t')

#drop index
df2.drop('index', axis = 1, inplace=True)

#copy df to dock_tructure_df
nontestset_selfdock_structure_df = df2.copy()
# dock_structure_df.drop(['PDBID','State'], axis = 1, inplace = True)
nontestset_selfdock_structure_df.drop(['State'], axis = 1, inplace = True)

# add entry_type field
nontestset_selfdock_structure_df['entry_type'] = 'self-docked active'

# %%
# read data for best scoring docked poses of inactive molecules that weren't in the old test set
df3 = pd.read_csv('data/crossdock_docking_data/crossdock_interaction_energies.txt', sep=',')

#drop index
df3.drop('index', axis = 1, inplace=True)

#copy df to dock_tructure_df
crossdock_structure_df = df3.copy()
# dock_structure_df.drop(['PDBID','State'], axis = 1, inplace = True)
crossdock_structure_df.drop(['State'], axis = 1, inplace = True)

# add entry_type field
crossdock_structure_df['entry_type'] = 'cross-docked active'

# %%
print('ED structures:', len(structure_df))
print('DUD-E docked inactives:', len(dock_structure_df))
print('test set self docked actives:', len(selfdock_structure_df))
print('non-test set self docked actives:', len(nontestset_selfdock_structure_df))
print('cross docked actives:', len(crossdock_structure_df))
print('total structures:', len(structure_df) + len(dock_structure_df) + len(selfdock_structure_df) + len(nontestset_selfdock_structure_df) + len(crossdock_structure_df))
# Out:
# ED structures: 364
# DUD-E docked inactives: 285
# test set self docked actives: 105
# non-test set self docked actives: 259
# cross docked actives: 331
# total structures: 1344

# %%
# join all datasets
frames = [structure_df, dock_structure_df, selfdock_structure_df, nontestset_selfdock_structure_df, crossdock_structure_df] 
structure_df = pd.concat(frames)

# reset index of structure_df
structure_df.reset_index(inplace = True, drop = True)

# %%
structure_df
# Out:
#      PDBID Function  1.21_intenergysum 1.21_inttype1  1.21_intenergy1  \
# 0     7EW2  Agonist                NaN           NaN              NaN
# 1     7EW3  Agonist                NaN           NaN              NaN
# 2     7EW4  Agonist                NaN           NaN              NaN
# 3     7EW1  Agonist                NaN           NaN              NaN
# 4     7LD4  Agonist                NaN           NaN              NaN
# ...    ...      ...                ...           ...              ...
# 1339  7VUG  Agonist                NaN           NaN              NaN
# 1340  7VUG  Agonist                NaN           NaN              NaN
# 1341  7VUG  Agonist                NaN           NaN              NaN
# 1342  7S8L  Agonist                NaN           NaN              NaN
# 1343  7TD4  Agonist                NaN           NaN              NaN
#
#      1.21_inttype2  1.21_intenergy2  1.22_intenergysum 1.22_inttype1  \
# 0              NaN              NaN                NaN           NaN
# 1              NaN              NaN                NaN           NaN
# 2              NaN              NaN                NaN           NaN
# 3              NaN              NaN                NaN           NaN
# 4              NaN              NaN                NaN           NaN
# ...            ...              ...                ...           ...
# 1339           NaN              NaN                NaN           NaN
# 1340           NaN              NaN                NaN           NaN
# 1341           NaN              NaN                NaN           NaN
# 1342           NaN              NaN                NaN           NaN
# 1343           NaN              NaN                NaN           NaN
#
#       1.22_intenergy1  ... 7.68_inttype1  7.68_intenergy1  7.68_inttype2  \
# 0                 NaN  ...           NaN              NaN            NaN
# 1                 NaN  ...           NaN              NaN            NaN
# 2                 NaN  ...           NaN              NaN            NaN
# 3                 NaN  ...           NaN              NaN            NaN
# 4                 NaN  ...           NaN              NaN            NaN
# ...               ...  ...           ...              ...            ...
# 1339              NaN  ...          None              0.0           None
# 1340              NaN  ...          None              0.0           None
# 1341              NaN  ...          None              0.0           None
# 1342              NaN  ...           NaN              NaN            NaN
# 1343              NaN  ...           NaN              NaN            NaN
#
#      7.68_intenergy2                        entry_type 5.28_intenergysum  \
# 0                NaN  experimentally determined active               NaN
# 1                NaN  experimentally determined active               NaN
# 2                NaN  experimentally determined active               NaN
# 3                NaN  experimentally determined active               NaN
# 4                NaN  experimentally determined active               NaN
# ...              ...                               ...               ...
# 1339             0.0               cross-docked active               NaN
# 1340             0.0               cross-docked active               NaN
# 1341             0.0               cross-docked active               NaN
# 1342             NaN               cross-docked active               NaN
# 1343             NaN               cross-docked active               NaN
#
#       5.28_inttype1  5.28_intenergy1 5.28_inttype2  5.28_intenergy2
# 0               NaN              NaN           NaN              NaN
# 1               NaN              NaN           NaN              NaN
# 2               NaN              NaN           NaN              NaN
# 3               NaN              NaN           NaN              NaN
# 4               NaN              NaN           NaN              NaN
# ...             ...              ...           ...              ...
# 1339            NaN              NaN           NaN              NaN
# 1340            NaN              NaN           NaN              NaN
# 1341            NaN              NaN           NaN              NaN
# 1342            NaN              NaN           NaN              NaN
# 1343            NaN              NaN           NaN              NaN
#
# [1344 rows x 1668 columns]

# %%
# drop entries with bad ligand placement
PDBs_toremove = [
    '4LDL',
    '4LDO',
    '7VDL',
    '7VDM',
    '7VUY',
    '7VUZ',
    '7VV0',
    '7VV3',
    '7VV4',
    '7VV5',
    '7NA7',
    '7FIG',
    '7FIH',
    '7P02',
    '7P00',
    '4U15',
    '2YCX',
    '6YVR',
    '5T04',
    '4XEE',
    '4XES',
    '4GRV'
]

to_drop = []

for i in range(len(structure_df)):
    if structure_df.iloc[i,:]['PDBID'] in PDBs_toremove:
        to_drop.append(i)

structure_df.drop(to_drop, inplace = True)

# %%
len(PDBs_toremove)
# Out:
# 22

# %%
# get columns with 'sum' in their name
sum_cols = [col for col in structure_df.columns if 'sum' in col]

# create empty list for residue numbers
resnums = []

# loop through sum columns and count interactions that don't have nonzero energies
for col in sum_cols:
    resnum = col[:4]
    resnums.append(resnum)

# drop columns from df in which > 10% of entries are NaN
for resnum in resnums:
    intenergysum_col = resnum + '_intenergysum'
    inttype1_col = resnum + '_inttype1'
    intenergy1_col = resnum + '_intenergy1'
    inttype2_col = resnum + '_inttype2'
    intenergy2_col = resnum + '_intenergy2'
    
    print('structures with interactions at position', resnum, ':', structure_df[intenergysum_col][structure_df[intenergysum_col] != 0].value_counts().sum())
    if structure_df[intenergysum_col][structure_df[intenergysum_col] != 0].value_counts().sum() < 10:
        structure_df.drop([intenergysum_col, inttype1_col, intenergy1_col, inttype2_col, intenergy2_col], axis = 1, inplace = True)
        print('dropped columns for residue: ', resnum, '\n')
# Out:
# structures with interactions at position 1.21 : 0
# dropped columns for residue:  1.21
#
# structures with interactions at position 1.22 : 0
# dropped columns for residue:  1.22
#
# structures with interactions at position 1.23 : 0
# dropped columns for residue:  1.23
#
# structures with interactions at position 1.24 : 0
# dropped columns for residue:  1.24
#
# structures with interactions at position 1.25 : 0
# dropped columns for residue:  1.25
#
# structures with interactions at position 1.26 : 0
# dropped columns for residue:  1.26
#
# structures with interactions at position 1.27 : 4
# dropped columns for residue:  1.27
#
# structures with interactions at position 1.28 : 4
# dropped columns for residue:  1.28
#
# structures with interactions at position 1.29 : 0
# dropped columns for residue:  1.29
#
# structures with interactions at position 1.30 : 6
# dropped columns for residue:  1.30
#
# structures with interactions at position 1.31 : 21
# structures with interactions at position 1.32 : 2
# dropped columns for residue:  1.32
#
# structures with interactions at position 1.33 : 0
# dropped columns for residue:  1.33
#
# structures with interactions at position 1.34 : 4
# dropped columns for residue:  1.34
#
# structures with interactions at position 1.35 : 21
# structures with interactions at position 1.36 : 1
# dropped columns for residue:  1.36
#
# structures with interactions at position 1.37 : 0
# dropped columns for residue:  1.37
#
# structures with interactions at position 1.38 : 3
# dropped columns for residue:  1.38
#
# structures with interactions at position 1.39 : 37
# structures with interactions at position 1.40 : 0
# dropped columns for residue:  1.40
#
# structures with interactions at position 1.41 : 0
# dropped columns for residue:  1.41
#
# structures with interactions at position 1.42 : 12
# structures with interactions at position 1.43 : 5
# dropped columns for residue:  1.43
#
# structures with interactions at position 1.44 : 0
# dropped columns for residue:  1.44
#
# structures with interactions at position 1.45 : 0
# dropped columns for residue:  1.45
#
# structures with interactions at position 1.46 : 1
# dropped columns for residue:  1.46
#
# structures with interactions at position 1.47 : 0
# dropped columns for residue:  1.47
#
# structures with interactions at position 1.48 : 0
# dropped columns for residue:  1.48
#
# structures with interactions at position 1.49 : 0
# dropped columns for residue:  1.49
#
# structures with interactions at position 1.50 : 3
# dropped columns for residue:  1.50
#
# structures with interactions at position 1.51 : 0
# dropped columns for residue:  1.51
#
# structures with interactions at position 1.52 : 0
# dropped columns for residue:  1.52
#
# structures with interactions at position 1.53 : 0
# dropped columns for residue:  1.53
#
# structures with interactions at position 1.54 : 0
# dropped columns for residue:  1.54
#
# structures with interactions at position 1.55 : 0
# dropped columns for residue:  1.55
#
# structures with interactions at position 1.56 : 1
# dropped columns for residue:  1.56
#
# structures with interactions at position 1.57 : 1
# dropped columns for residue:  1.57
#
# structures with interactions at position 1.58 : 0
# dropped columns for residue:  1.58
#
# structures with interactions at position 1.59 : 0
# dropped columns for residue:  1.59
#
# structures with interactions at position 1.60 : 0
# dropped columns for residue:  1.60
#
# structures with interactions at position 2.34 : 0
# dropped columns for residue:  2.34
#
# structures with interactions at position 2.35 : 0
# dropped columns for residue:  2.35
#
# structures with interactions at position 2.36 : 0
# dropped columns for residue:  2.36
#
# structures with interactions at position 2.37 : 1
# dropped columns for residue:  2.37
#
# structures with interactions at position 2.38 : 6
# dropped columns for residue:  2.38
#
# structures with interactions at position 2.39 : 7
# dropped columns for residue:  2.39
#
# structures with interactions at position 2.40 : 4
# dropped columns for residue:  2.40
#
# structures with interactions at position 2.41 : 0
# dropped columns for residue:  2.41
#
# structures with interactions at position 2.42 : 1
# dropped columns for residue:  2.42
#
# structures with interactions at position 2.43 : 0
# dropped columns for residue:  2.43
#
# structures with interactions at position 2.44 : 0
# dropped columns for residue:  2.44
#
# structures with interactions at position 2.45 : 0
# dropped columns for residue:  2.45
#
# structures with interactions at position 2.46 : 2
# dropped columns for residue:  2.46
#
# structures with interactions at position 2.47 : 0
# dropped columns for residue:  2.47
#
# structures with interactions at position 2.48 : 0
# dropped columns for residue:  2.48
#
# structures with interactions at position 2.49 : 1
# dropped columns for residue:  2.49
#
# structures with interactions at position 2.50 : 6
# dropped columns for residue:  2.50
#
# structures with interactions at position 2.51 : 0
# dropped columns for residue:  2.51
#
# structures with interactions at position 2.52 : 0
# dropped columns for residue:  2.52
#
# structures with interactions at position 2.53 : 17
# structures with interactions at position 2.54 : 12
# structures with interactions at position 2.55 : 0
# dropped columns for residue:  2.55
#
# structures with interactions at position 2.56 : 11
# structures with interactions at position 2.57 : 88
# structures with interactions at position 2.58 : 13
# structures with interactions at position 2.59 : 3
# dropped columns for residue:  2.59
#
# structures with interactions at position 2.60 : 157
# structures with interactions at position 2.61 : 199
# structures with interactions at position 2.62 : 3
# dropped columns for residue:  2.62
#
# structures with interactions at position 2.63 : 51
# structures with interactions at position 2.64 : 233
# structures with interactions at position 2.65 : 80
# structures with interactions at position 2.66 : 3
# dropped columns for residue:  2.66
#
# structures with interactions at position 2.67 : 4
# dropped columns for residue:  2.67
#
# structures with interactions at position 2.68 : 8
# dropped columns for residue:  2.68
#
# structures with interactions at position 2.69 : 0
# dropped columns for residue:  2.69
#
# structures with interactions at position 2.70 : 0
# dropped columns for residue:  2.70
#
# structures with interactions at position 3.19 : 0
# dropped columns for residue:  3.19
#
# structures with interactions at position 3.20 : 0
# dropped columns for residue:  3.20
#
# structures with interactions at position 3.21 : 6
# dropped columns for residue:  3.21
#
# structures with interactions at position 3.22 : 3
# dropped columns for residue:  3.22
#
# structures with interactions at position 3.23 : 0
# dropped columns for residue:  3.23
#
# structures with interactions at position 3.24 : 1
# dropped columns for residue:  3.24
#
# structures with interactions at position 3.25 : 38
# structures with interactions at position 3.26 : 12
# structures with interactions at position 3.27 : 0
# dropped columns for residue:  3.27
#
# structures with interactions at position 3.28 : 254
# structures with interactions at position 3.29 : 307
# structures with interactions at position 3.30 : 15
# structures with interactions at position 3.31 : 0
# dropped columns for residue:  3.31
#
# structures with interactions at position 3.32 : 798
# structures with interactions at position 3.33 : 665
# structures with interactions at position 3.34 : 5
# dropped columns for residue:  3.34
#
# structures with interactions at position 3.35 : 12
# structures with interactions at position 3.36 : 380
# structures with interactions at position 3.37 : 133
# structures with interactions at position 3.38 : 0
# dropped columns for residue:  3.38
#
# structures with interactions at position 3.39 : 8
# dropped columns for residue:  3.39
#
# structures with interactions at position 3.40 : 16
# structures with interactions at position 3.41 : 4
# dropped columns for residue:  3.41
#
# structures with interactions at position 3.42 : 0
# dropped columns for residue:  3.42
#
# structures with interactions at position 3.43 : 0
# dropped columns for residue:  3.43
#
# structures with interactions at position 3.44 : 0
# dropped columns for residue:  3.44
#
# structures with interactions at position 3.45 : 2
# dropped columns for residue:  3.45
#
# structures with interactions at position 3.46 : 2
# dropped columns for residue:  3.46
#
# structures with interactions at position 3.47 : 1
# dropped columns for residue:  3.47
#
# structures with interactions at position 3.48 : 0
# dropped columns for residue:  3.48
#
# structures with interactions at position 3.49 : 6
# dropped columns for residue:  3.49
#
# structures with interactions at position 3.50 : 4
# dropped columns for residue:  3.50
#
# structures with interactions at position 3.51 : 0
# dropped columns for residue:  3.51
#
# structures with interactions at position 3.52 : 1
# dropped columns for residue:  3.52
#
# structures with interactions at position 3.53 : 5
# dropped columns for residue:  3.53
#
# structures with interactions at position 3.54 : 1
# dropped columns for residue:  3.54
#
# structures with interactions at position 3.55 : 0
# dropped columns for residue:  3.55
#
# structures with interactions at position 3.56 : 0
# dropped columns for residue:  3.56
#
# structures with interactions at position 3.57 : 0
# dropped columns for residue:  3.57
#
# structures with interactions at position 3.58 : 0
# dropped columns for residue:  3.58
# structures with interactions at position 3.59 : 0
# dropped columns for residue:  3.59
#
# structures with interactions at position 3.60 : 0
# dropped columns for residue:  3.60
#
# structures with interactions at position 3.61 : 0
# dropped columns for residue:  3.61
#
# structures with interactions at position 3.62 : 0
# dropped columns for residue:  3.62
#
# structures with interactions at position 3.63 : 0
# dropped columns for residue:  3.63
#
# structures with interactions at position 3.64 : 0
# dropped columns for residue:  3.64
#
# structures with interactions at position 3.65 : 0
# dropped columns for residue:  3.65
#
# structures with interactions at position 3.66 : 0
# dropped columns for residue:  3.66
#
# structures with interactions at position 3.67 : 0
# dropped columns for residue:  3.67
#
# structures with interactions at position 3.68 : 0
# dropped columns for residue:  3.68
#
# structures with interactions at position 3.69 : 0
# dropped columns for residue:  3.69
#
# structures with interactions at position 3.70 : 0
# dropped columns for residue:  3.70
#
# structures with interactions at position 3.71 : 0
# dropped columns for residue:  3.71
#
# structures with interactions at position 4.29 : 0
# dropped columns for residue:  4.29
#
# structures with interactions at position 4.30 : 0
# dropped columns for residue:  4.30
#
# structures with interactions at position 4.31 : 0
# dropped columns for residue:  4.31
#
# structures with interactions at position 4.32 : 0
# dropped columns for residue:  4.32
#
# structures with interactions at position 4.33 : 0
# dropped columns for residue:  4.33
#
# structures with interactions at position 4.34 : 0
# dropped columns for residue:  4.34
#
# structures with interactions at position 4.35 : 0
# dropped columns for residue:  4.35
#
# structures with interactions at position 4.36 : 0
# dropped columns for residue:  4.36
#
# structures with interactions at position 4.37 : 0
# dropped columns for residue:  4.37
#
# structures with interactions at position 4.38 : 0
# dropped columns for residue:  4.38
#
# structures with interactions at position 4.39 : 1
# dropped columns for residue:  4.39
#
# structures with interactions at position 4.40 : 0
# dropped columns for residue:  4.40
#
# structures with interactions at position 4.41 : 2
# dropped columns for residue:  4.41
#
# structures with interactions at position 4.42 : 1
# dropped columns for residue:  4.42
#
# structures with interactions at position 4.43 : 0
# dropped columns for residue:  4.43
#
# structures with interactions at position 4.44 : 0
# dropped columns for residue:  4.44
#
# structures with interactions at position 4.45 : 4
# dropped columns for residue:  4.45
#
# structures with interactions at position 4.46 : 2
# dropped columns for residue:  4.46
#
# structures with interactions at position 4.47 : 0
# dropped columns for residue:  4.47
#
# structures with interactions at position 4.48 : 0
# dropped columns for residue:  4.48
#
# structures with interactions at position 4.49 : 0
# dropped columns for residue:  4.49
#
# structures with interactions at position 4.50 : 3
# dropped columns for residue:  4.50
#
# structures with interactions at position 4.51 : 0
# dropped columns for residue:  4.51
#
# structures with interactions at position 4.52 : 2
# dropped columns for residue:  4.52
#
# structures with interactions at position 4.53 : 3
# dropped columns for residue:  4.53
#
# structures with interactions at position 4.54 : 2
# dropped columns for residue:  4.54
#
# structures with interactions at position 4.55 : 0
# dropped columns for residue:  4.55
#
# structures with interactions at position 4.56 : 15
# structures with interactions at position 4.57 : 40
# structures with interactions at position 4.58 : 5
# dropped columns for residue:  4.58
#
# structures with interactions at position 4.59 : 0
# dropped columns for residue:  4.59
#
# structures with interactions at position 4.60 : 73
# structures with interactions at position 4.61 : 5
# dropped columns for residue:  4.61
#
# structures with interactions at position 4.62 : 0
# dropped columns for residue:  4.62
#
# structures with interactions at position 4.63 : 0
# dropped columns for residue:  4.63
#
# structures with interactions at position 4.64 : 5
# dropped columns for residue:  4.64
#
# structures with interactions at position 4.65 : 1
# dropped columns for residue:  4.65
#
# structures with interactions at position 4.66 : 4
# dropped columns for residue:  4.66
#
# structures with interactions at position 4.67 : 0
# dropped columns for residue:  4.67
#
# structures with interactions at position 4.68 : 0
# dropped columns for residue:  4.68
#
# structures with interactions at position 4.69 : 0
# dropped columns for residue:  4.69
#
# structures with interactions at position 5.29 : 0
# dropped columns for residue:  5.29
#
# structures with interactions at position 5.30 : 0
# dropped columns for residue:  5.30
#
# structures with interactions at position 5.31 : 12
# structures with interactions at position 5.32 : 0
# dropped columns for residue:  5.32
#
# structures with interactions at position 5.33 : 0
# dropped columns for residue:  5.33
#
# structures with interactions at position 5.34 : 3
# dropped columns for residue:  5.34
#
# structures with interactions at position 5.35 : 58
# structures with interactions at position 5.36 : 9
# dropped columns for residue:  5.36
#
# structures with interactions at position 5.37 : 1
# dropped columns for residue:  5.37
#
# structures with interactions at position 5.38 : 176
# structures with interactions at position 5.39 : 174
# structures with interactions at position 5.40 : 31
# structures with interactions at position 5.41 : 10
# structures with interactions at position 5.42 : 391
# structures with interactions at position 5.43 : 100
# structures with interactions at position 5.44 : 9
# dropped columns for residue:  5.44
#
# structures with interactions at position 5.45 : 1
# dropped columns for residue:  5.45
#
# structures with interactions at position 5.46 : 181
# structures with interactions at position 5.47 : 48
# structures with interactions at position 5.48 : 2
# dropped columns for residue:  5.48
#
# structures with interactions at position 5.49 : 1
# dropped columns for residue:  5.49
#
# structures with interactions at position 5.50 : 1
# dropped columns for residue:  5.50
#
# structures with interactions at position 5.51 : 2
# dropped columns for residue:  5.51
#
# structures with interactions at position 5.52 : 0
# dropped columns for residue:  5.52
#
# structures with interactions at position 5.53 : 1
# dropped columns for residue:  5.53
#
# structures with interactions at position 5.54 : 0
# dropped columns for residue:  5.54
#
# structures with interactions at position 5.55 : 0
# dropped columns for residue:  5.55
#
# structures with interactions at position 5.56 : 0
# dropped columns for residue:  5.56
#
# structures with interactions at position 5.57 : 0
# dropped columns for residue:  5.57
#
# structures with interactions at position 5.58 : 0
# dropped columns for residue:  5.58
#
# structures with interactions at position 5.59 : 0
# dropped columns for residue:  5.59
#
# structures with interactions at position 5.60 : 0
# dropped columns for residue:  5.60
#
# structures with interactions at position 5.61 : 0
# dropped columns for residue:  5.61
#
# structures with interactions at position 5.62 : 0
# dropped columns for residue:  5.62
#
# structures with interactions at position 5.63 : 0
# dropped columns for residue:  5.63
#
# structures with interactions at position 5.64 : 0
# dropped columns for residue:  5.64
#
# structures with interactions at position 5.65 : 0
# dropped columns for residue:  5.65
#
# structures with interactions at position 5.66 : 0
# dropped columns for residue:  5.66
#
# structures with interactions at position 5.67 : 0
# dropped columns for residue:  5.67
#
# structures with interactions at position 5.68 : 0
# dropped columns for residue:  5.68
#
# structures with interactions at position 5.69 : 0
# dropped columns for residue:  5.69
#
# structures with interactions at position 5.70 : 0
# dropped columns for residue:  5.70
#
# structures with interactions at position 5.71 : 0
# dropped columns for residue:  5.71
#
# structures with interactions at position 5.72 : 0
# dropped columns for residue:  5.72
#
# structures with interactions at position 5.73 : 0
# dropped columns for residue:  5.73
#
# structures with interactions at position 5.74 : 0
# dropped columns for residue:  5.74
#
# structures with interactions at position 5.75 : 0
# dropped columns for residue:  5.75
#
# structures with interactions at position 5.76 : 0
# dropped columns for residue:  5.76
#
# structures with interactions at position 5.77 : 0
# dropped columns for residue:  5.77
#
# structures with interactions at position 5.78 : 0
# dropped columns for residue:  5.78
# structures with interactions at position 5.79 : 0
# dropped columns for residue:  5.79
#
# structures with interactions at position 5.80 : 0
# dropped columns for residue:  5.80
#
# structures with interactions at position 5.81 : 0
# dropped columns for residue:  5.81
#
# structures with interactions at position 5.82 : 0
# dropped columns for residue:  5.82
#
# structures with interactions at position 5.83 : 0
# dropped columns for residue:  5.83
#
# structures with interactions at position 5.84 : 0
# dropped columns for residue:  5.84
#
# structures with interactions at position 5.85 : 0
# dropped columns for residue:  5.85
#
# structures with interactions at position 5.86 : 0
# dropped columns for residue:  5.86
#
# structures with interactions at position 5.87 : 0
# dropped columns for residue:  5.87
#
# structures with interactions at position 6.15 : 0
# dropped columns for residue:  6.15
#
# structures with interactions at position 6.16 : 0
# dropped columns for residue:  6.16
#
# structures with interactions at position 6.17 : 0
# dropped columns for residue:  6.17
#
# structures with interactions at position 6.18 : 0
# dropped columns for residue:  6.18
#
# structures with interactions at position 6.19 : 0
# dropped columns for residue:  6.19
#
# structures with interactions at position 6.20 : 0
# dropped columns for residue:  6.20
#
# structures with interactions at position 6.21 : 0
# dropped columns for residue:  6.21
#
# structures with interactions at position 6.22 : 0
# dropped columns for residue:  6.22
#
# structures with interactions at position 6.23 : 0
# dropped columns for residue:  6.23
#
# structures with interactions at position 6.24 : 0
# dropped columns for residue:  6.24
#
# structures with interactions at position 6.25 : 0
# dropped columns for residue:  6.25
#
# structures with interactions at position 6.26 : 0
# dropped columns for residue:  6.26
#
# structures with interactions at position 6.27 : 0
# dropped columns for residue:  6.27
#
# structures with interactions at position 6.28 : 0
# dropped columns for residue:  6.28
#
# structures with interactions at position 6.29 : 4
# dropped columns for residue:  6.29
#
# structures with interactions at position 6.30 : 2
# dropped columns for residue:  6.30
#
# structures with interactions at position 6.31 : 0
# dropped columns for residue:  6.31
#
# structures with interactions at position 6.32 : 2
# dropped columns for residue:  6.32
#
# structures with interactions at position 6.33 : 6
# dropped columns for residue:  6.33
#
# structures with interactions at position 6.34 : 1
# dropped columns for residue:  6.34
#
# structures with interactions at position 6.35 : 0
# dropped columns for residue:  6.35
#
# structures with interactions at position 6.36 : 3
# dropped columns for residue:  6.36
#
# structures with interactions at position 6.37 : 2
# dropped columns for residue:  6.37
#
# structures with interactions at position 6.38 : 0
# dropped columns for residue:  6.38
#
# structures with interactions at position 6.39 : 2
# dropped columns for residue:  6.39
#
# structures with interactions at position 6.40 : 2
# dropped columns for residue:  6.40
#
# structures with interactions at position 6.41 : 0
# dropped columns for residue:  6.41
#
# structures with interactions at position 6.42 : 0
# dropped columns for residue:  6.42
#
# structures with interactions at position 6.43 : 0
# dropped columns for residue:  6.43
#
# structures with interactions at position 6.44 : 8
# dropped columns for residue:  6.44
#
# structures with interactions at position 6.45 : 1
# dropped columns for residue:  6.45
#
# structures with interactions at position 6.46 : 0
# dropped columns for residue:  6.46
#
# structures with interactions at position 6.47 : 4
# dropped columns for residue:  6.47
#
# structures with interactions at position 6.48 : 380
# structures with interactions at position 6.49 : 5
# dropped columns for residue:  6.49
#
# structures with interactions at position 6.50 : 4
# dropped columns for residue:  6.50
#
# structures with interactions at position 6.51 : 718
# structures with interactions at position 6.52 : 531
# structures with interactions at position 6.53 : 2
# dropped columns for residue:  6.53
#
# structures with interactions at position 6.54 : 43
# structures with interactions at position 6.55 : 548
# structures with interactions at position 6.56 : 4
# dropped columns for residue:  6.56
#
# structures with interactions at position 6.57 : 8
# dropped columns for residue:  6.57
#
# structures with interactions at position 6.58 : 96
# structures with interactions at position 6.59 : 26
# structures with interactions at position 6.60 : 4
# dropped columns for residue:  6.60
#
# structures with interactions at position 6.61 : 0
# dropped columns for residue:  6.61
#
# structures with interactions at position 6.62 : 8
# dropped columns for residue:  6.62
#
# structures with interactions at position 6.63 : 0
# dropped columns for residue:  6.63
#
# structures with interactions at position 6.64 : 0
# dropped columns for residue:  6.64
#
# structures with interactions at position 6.65 : 0
# dropped columns for residue:  6.65
#
# structures with interactions at position 6.66 : 0
# dropped columns for residue:  6.66
#
# structures with interactions at position 6.67 : 0
# dropped columns for residue:  6.67
#
# structures with interactions at position 6.68 : 0
# dropped columns for residue:  6.68
#
# structures with interactions at position 7.21 : 0
# dropped columns for residue:  7.21
#
# structures with interactions at position 7.22 : 0
# dropped columns for residue:  7.22
#
# structures with interactions at position 7.23 : 0
# dropped columns for residue:  7.23
#
# structures with interactions at position 7.24 : 0
# dropped columns for residue:  7.24
#
# structures with interactions at position 7.25 : 0
# dropped columns for residue:  7.25
#
# structures with interactions at position 7.26 : 0
# dropped columns for residue:  7.26
#
# structures with interactions at position 7.27 : 0
# dropped columns for residue:  7.27
#
# structures with interactions at position 7.28 : 1
# dropped columns for residue:  7.28
#
# structures with interactions at position 7.29 : 3
# dropped columns for residue:  7.29
#
# structures with interactions at position 7.30 : 1
# dropped columns for residue:  7.30
#
# structures with interactions at position 7.31 : 15
# structures with interactions at position 7.32 : 104
# structures with interactions at position 7.33 : 3
# dropped columns for residue:  7.33
#
# structures with interactions at position 7.34 : 10
# structures with interactions at position 7.35 : 265
# structures with interactions at position 7.36 : 173
# structures with interactions at position 7.37 : 5
# dropped columns for residue:  7.37
#
# structures with interactions at position 7.38 : 19
# structures with interactions at position 7.39 : 644
# structures with interactions at position 7.40 : 55
# structures with interactions at position 7.41 : 3
# dropped columns for residue:  7.41
#
# structures with interactions at position 7.42 : 111
# structures with interactions at position 7.43 : 209
# structures with interactions at position 7.44 : 0
# dropped columns for residue:  7.44
#
# structures with interactions at position 7.45 : 6
# dropped columns for residue:  7.45
#
# structures with interactions at position 7.46 : 20
# structures with interactions at position 7.47 : 5
# dropped columns for residue:  7.47
#
# structures with interactions at position 7.48 : 0
# dropped columns for residue:  7.48
#
# structures with interactions at position 7.49 : 3
# dropped columns for residue:  7.49
#
# structures with interactions at position 7.50 : 0
# dropped columns for residue:  7.50
#
# structures with interactions at position 7.51 : 0
# dropped columns for residue:  7.51
#
# structures with interactions at position 7.52 : 1
# dropped columns for residue:  7.52
#
# structures with interactions at position 7.53 : 2
# dropped columns for residue:  7.53
#
# structures with interactions at position 7.54 : 0
# dropped columns for residue:  7.54
#
# structures with interactions at position 7.55 : 0
# dropped columns for residue:  7.55
#
# structures with interactions at position 7.56 : 1
# dropped columns for residue:  7.56
#
# structures with interactions at position 7.57 : 0
# dropped columns for residue:  7.57
#
# structures with interactions at position 7.58 : 0
# dropped columns for residue:  7.58
#
# structures with interactions at position 7.59 : 0
# dropped columns for residue:  7.59
#
# structures with interactions at position 7.60 : 0
# dropped columns for residue:  7.60
#
# structures with interactions at position 7.61 : 0
# dropped columns for residue:  7.61
#
# structures with interactions at position 7.62 : 0
# dropped columns for residue:  7.62
#
# structures with interactions at position 7.63 : 0
# dropped columns for residue:  7.63
#
# structures with interactions at position 7.64 : 0
# dropped columns for residue:  7.64
#
# structures with interactions at position 7.65 : 0
# dropped columns for residue:  7.65
#
# structures with interactions at position 7.66 : 0
# dropped columns for residue:  7.66
#
# structures with interactions at position 7.67 : 0
# dropped columns for residue:  7.67
#
# structures with interactions at position 7.68 : 0
# dropped columns for residue:  7.68
#
# structures with interactions at position 5.28 : 0
# dropped columns for residue:  5.28

# %%
# plot displaying number of each entry type
structure_df['entry_type'].hist()
# Out:
# <AxesSubplot:>

# %%
structure_df['Function'].value_counts()
# Out:
# Antagonist           532
# Agonist              372
# Inactive             285
# Inverse agonist       73
# Agonist (partial)     33
# Name: Function, dtype: int64

# %%
structure_df['entry_type'].value_counts().sort_index()
# Out:
# cross-docked active                 326
# docked inactive                     285
# experimentally determined active    342
# self-docked active                  342
# Name: entry_type, dtype: int64

# %%
structure_df['entry_type'].value_counts().sum() # number of entries in the dataset
# Out:
# 1295

# %%
# pie chart

# color key
colors = {'experimentally determined active': 'tab:blue',
           'self-docked active': 'tab:orange',
            'cross-docked active': 'tab:purple',
             'docked inactive': 'tab:green',}

import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (5,5)
plt.rcParams['figure.dpi'] = 300

values=structure_df['entry_type'].value_counts(dropna=True).sort_index()
vc = structure_df['entry_type'].value_counts(dropna=True).sort_index()
labels = vc.index

plt.pie(list(structure_df['entry_type'].value_counts().sort_index()),
        labels = labels,
        autopct= lambda x: '{:.0f}'.format(x*values.sum()/100),
        colors = [colors[key] for key in labels]
       )
plt.show()

# %%
# drop entry_type field but save it for later
entry_types = structure_df['entry_type']
structure_df.drop(['entry_type'], axis = 1, inplace = True)

# %%
# simplification: replace partial agonist with agonist
structure_df = structure_df.replace('Agonist (partial)', 'Agonist')

# %%
actual_fxns = structure_df['Function']

# %%
actual_fxns.unique()
# Out:
# array(['Agonist', 'Antagonist', 'Inverse agonist', 'Inactive'],
#       dtype=object)

# %% [markdown]
# ## Label Encoding

# %%
# convert inttype columns to string and get unique interaction types
interaction_types = []
inttype_cols = [col for col in structure_df.columns if 'inttype' in col]

for col in inttype_cols:
    structure_df[col] = structure_df[col].astype(str)
    uniq_col_ints = list(structure_df[col].unique())
    for interaction in uniq_col_ints:
        if interaction not in interaction_types:
            interaction_types.append(interaction)

# %%
interaction_types
# Out:
# ['nan', 'None', 'Hbond', 'Distance', 'Arene', 'Ionic', 'Covalent']

# %%
# custom encoding for inttypes
custom_mapping = {'nan' : 0, 'None' : 1, 'Hbond' : 2, 'Distance' : 3, 'Arene' : 4, 'Ionic' : 5, 'Covalent' : 6}

for col in inttype_cols:
    structure_df[col] = structure_df[col].map(custom_mapping)
    
# LabelEncoder for Function labels
le = LabelEncoder()

# get Function columns
cols = [col for col in structure_df.columns if 'Function' in col]

# loop though all columns and convert strings to categorical integer variable
for col in cols:
    structure_df[col] = le.fit_transform(structure_df[col])

# %%
le.classes_
# Out:
# array(['Agonist', 'Antagonist', 'Inactive', 'Inverse agonist'],
#       dtype=object)

# %%
# assign target classes to y
y = structure_df['Function']

# assign data to X
X = structure_df.drop(['Function'], axis = 1)

# create actual_state column with non-encoded states
X['actual_fxn'] = actual_fxns

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
def scale_impute(dataframe):
    # get colnames
    colnames = list(dataframe.drop(['actual_fxn', 'PDBID'], axis = 1).columns)
    fxns_df = dataframe['actual_fxn']
    #state_df.reset_index(inplace=True)
    df = dataframe.drop(['actual_fxn'], axis = 1)
    PDBIDs = list(dataframe['PDBID'])

    # impute data
    from sklearn.impute import SimpleImputer
    my_imputer = SimpleImputer()
    df_imputed = pd.DataFrame(my_imputer.fit_transform(df.iloc[:,1:]))

    # scale data
    scaler = StandardScaler()
    # scaler = MinMaxScaler()
    to_scale = [col for col in df_imputed.columns.values]
    scaler.fit(df_imputed[to_scale])

    # predict z-scores on the test set
    df_imputed[to_scale] = scaler.transform(df_imputed[to_scale]) 

    # #rename columns
    df_imputed.columns = colnames
    
    df_imputed.insert(0, 'PDBID',  PDBIDs)

    # display scaled values
    display(df_imputed)
    
    return(df_imputed, fxns_df)

# %%
(X_train_imputed, X_train_fxns) = scale_impute(X_train)
(X_test_imputed, X_test_fxns) = scale_impute(X_test)
# Out:
#     PDBID  1.31_intenergysum  1.31_inttype1  1.31_intenergy1  1.31_inttype2  \
# 0    7E2Y       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# 1    3NY8       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# 2    7WF7       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# 3    3PBL       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# 4    3EML       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# ..    ...                ...            ...              ...            ...
# 966  7DH5       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# 967  6TP6       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# 968  5WIU       3.128547e-17      -0.978137    -5.549546e-17      -0.959821
# 969  4PY0       1.657197e-01       0.656581     1.544339e-01       0.644286
# 970  5NM4       1.657197e-01       0.656581     1.544339e-01       0.644286
#
#      1.31_intenergy2  1.35_intenergysum  1.35_inttype1  1.35_intenergy1  \
# 0           0.000000       8.690069e-02      -0.199360     8.460177e-02
# 1           0.000000       8.690069e-02      -0.199360     8.460177e-02
# 2           0.000000       8.690069e-02      -0.199360     8.460177e-02
# 3           0.000000       9.788194e-18      -1.959163    -1.072041e-17
# 4           0.000000       8.690069e-02       3.320247     8.460177e-02
# ..               ...                ...            ...              ...
# 966         0.000000       8.690069e-02      -0.199360     8.460177e-02
# 967         0.000000       8.690069e-02      -0.199360     8.460177e-02
# 968         0.000000       8.690069e-02      -0.199360     8.460177e-02
# 969         0.128212       8.690069e-02      -0.199360     8.460177e-02
# 970         0.128212       8.690069e-02      -0.199360     8.460177e-02
#
#      1.35_inttype2  ...  7.43_intenergysum  7.43_inttype1  7.43_intenergy1  \
# 0        -0.121502  ...           0.063977       1.667607         0.042421
# 1        -0.121502  ...           0.132117       0.696253         0.142886
# 2        -0.121502  ...           0.132117      -1.246454         0.142886
# 3        -2.228264  ...           0.132117       0.696253         0.142886
# 4         4.092021  ...           0.132117      -1.246454         0.142886
# ..             ...  ...                ...            ...              ...
# 966      -0.121502  ...           0.132117       0.696253         0.142886
# 967      -0.121502  ...           0.132117       0.696253         0.142886
# 968      -0.121502  ...           0.132117       0.696253         0.142886
# 969      -0.121502  ...           0.132117      -1.246454         0.142886
# 970      -0.121502  ...           0.132117      -1.246454         0.142886
#
#      7.43_inttype2  7.43_intenergy2  7.46_intenergysum  7.46_inttype1  \
# 0         0.807957         0.080826            0.08228      -0.163404
# 1         0.807957         0.080826            0.08228      -0.163404
# 2        -1.185757         0.080826            0.08228      -0.163404
# 3         0.807957         0.080826            0.08228      -0.163404
# 4        -1.185757         0.080826            0.08228      -0.163404
# ..             ...              ...                ...            ...
# 966      -1.185757         0.080826            0.08228      -0.163404
# 967       0.807957         0.080826            0.08228      -0.163404
# 968       0.807957         0.080826            0.08228      -0.163404
# 969      -1.185757         0.080826            0.08228      -0.163404
# 970      -1.185757         0.080826            0.08228      -0.163404
#
#      7.46_intenergy1  7.46_inttype2  7.46_intenergy2
# 0           0.076444      -0.157525         0.033067
# 1           0.076444      -0.157525         0.033067
# 2           0.076444      -0.157525         0.033067
# 3           0.076444      -0.157525         0.033067
# 4           0.076444      -0.157525         0.033067
# ..               ...            ...              ...
# 966         0.076444      -0.157525         0.033067
# 967         0.076444      -0.157525         0.033067
# 968         0.076444      -0.157525         0.033067
# 969         0.076444      -0.157525         0.033067
# 970         0.076444      -0.157525         0.033067
#
# [971 rows x 281 columns]
#     PDBID  1.31_intenergysum  1.31_inttype1  1.31_intenergy1  1.31_inttype2  \
# 0    5D5A           0.243829       0.568420         0.241197       0.455931
# 1    6ZFZ           0.243829       0.568420         0.241197       0.455931
# 2    6VMS           0.000000      -0.966315         0.000000      -0.851340
# 3    7DHR           0.243829       0.568420         0.241197       0.455931
# 4    6H7N           0.000000      -0.966315         0.000000      -0.851340
# ..    ...                ...            ...              ...            ...
# 319  5NM4           0.243829       0.568420         0.241197       0.455931
# 320  3ODU           0.243829       0.568420         0.241197       0.455931
# 321  6PS3           0.243829       0.568420         0.241197       0.455931
# 322  7VOE           0.000000      -0.966315         0.000000      -0.851340
# 323  6HLL           0.243829       0.568420         0.241197       0.455931
#
#      1.31_intenergy2  1.35_intenergysum  1.35_inttype1  1.35_intenergy1  \
# 0           0.185575           0.174273      -0.192788         0.185933
# 1           0.185575           0.174273      -0.192788         0.185933
# 2           0.000000           0.174273      -0.192788         0.185933
# 3           0.185575           0.174273      -0.192788         0.185933
# 4           0.000000           0.174273      -0.192788         0.185933
# ..               ...                ...            ...              ...
# 319         0.185575           0.174273      -0.192788         0.185933
# 320         0.185575          -2.265554       1.408838        -3.904592
# 321         0.185575           0.174273      -0.192788         0.185933
# 322         0.000000           0.174273      -0.192788         0.185933
# 323         0.185575           0.174273      -0.192788         0.185933
#
#      1.35_inttype2  ...  7.43_intenergysum  7.43_inttype1  7.43_intenergy1  \
# 0        -0.115249  ...           0.213774       0.642753         0.184985
# 1        -0.115249  ...          -0.689654       1.576618        -0.756404
# 2        -0.115249  ...          -0.388511       1.576618        -0.442608
# 3        -0.115249  ...           0.213774       0.642753         0.184985
# 4        -0.115249  ...           0.213774       0.642753         0.184985
# ..             ...  ...                ...            ...              ...
# 319      -0.115249  ...           0.213774       0.642753         0.184985
# 320      -0.115249  ...           0.213774      -1.224977         0.184985
# 321      -0.115249  ...           0.213774       0.642753         0.184985
# 322      -0.115249  ...           0.213774      -1.224977         0.184985
# 323      -0.115249  ...           0.213774      -1.224977         0.184985
#
#      7.43_inttype2  7.43_intenergy2  7.46_intenergysum  7.46_inttype1  \
# 0         0.835398         0.158122           0.085303      -0.176608
# 1         0.835398         0.158122           0.085303      -0.176608
# 2         0.835398         0.158122           0.085303      -0.176608
# 3         0.835398         0.158122           0.085303      -0.176608
# 4         0.835398         0.158122           0.085303      -0.176608
# ..             ...              ...                ...            ...
# 319       0.835398         0.158122           0.085303      -0.176608
# 320      -1.125971         0.158122           0.085303      -0.176608
# 321      -1.125971         0.158122           0.085303      -0.176608
# 322      -1.125971         0.158122           0.085303      -0.176608
# 323      -1.125971         0.158122           0.085303      -0.176608
#
#      7.46_intenergy1  7.46_inttype2  7.46_intenergy2
# 0           0.066909      -0.154341         0.058014
# 1           0.066909      -0.154341         0.058014
# 2           0.066909      -0.154341         0.058014
# 3           0.066909      -0.154341         0.058014
# 4           0.066909      -0.154341         0.058014
# ..               ...            ...              ...
# 319         0.066909      -0.154341         0.058014
# 320         0.066909      -0.154341         0.058014
# 321         0.066909      -0.154341         0.058014
# 322         0.066909      -0.154341         0.058014
# 323         0.066909      -0.154341         0.058014
#
# [324 rows x 281 columns]

# %%
plt.rcParams["figure.figsize"] = (2,2)
plt.rcParams['figure.dpi'] = 150
X_train_imputed['3.32_intenergysum'].hist()
# Out:
# <AxesSubplot:>

# %%
X_train_fxns = X_train_fxns.reset_index()
X_train_fxns.drop(['index'], axis = 1, inplace = True)

X_test_fxns = X_test_fxns.reset_index()
X_test_fxns.drop(['index'], axis = 1, inplace = True)

# %%
def train_test_predict(train_df, train_y, test_df, test_y, encoder):
    #Import Random Forest Model
    from sklearn.ensemble import RandomForestClassifier

    #Create a Gaussian Classifier
    clf=RandomForestClassifier(n_estimators=1000, random_state=1, class_weight = 'balanced_subsample')

    #Train the model using the training sets y_pred=clf.predict(X_test)
    clf.fit(train_df.iloc[:, 1:], train_y)
    
    # print classes able to be predicted by the model (check 8/1/22)
    # print(clf.classes_)
    
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import cross_val_score, KFold
    import numpy as np

    # cross-validation
    scores = cross_val_score(clf, train_df.iloc[:, 1:], train_y, cv=5)
    print("Mean cross-validation score: %.2f" % scores.mean())

    # k-fold CV
    kfold = KFold(n_splits=10, shuffle=True, random_state = 1)
    kf_cv_scores = cross_val_score(clf, train_df.iloc[:, 1:], train_y, cv=kfold)
    print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
    
    # test set predictions
    y_pred = clf.predict(test_df.iloc[:, 1:])
    
    # print unique classes predicted on the testing data (check 8/1/22)
    # print(np.unique(y_pred))

    #Import scikit-learn metrics module for accuracy calculation
    from sklearn import metrics

    # reverse label encoding
    y_pred_actual = encoder.inverse_transform(y_pred)
    y_test_actual = encoder.inverse_transform(test_y)

    data = {'y_Actual':    y_test_actual,
            'y_Predicted': y_pred_actual
            }

    df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])

    confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
    print ('\n', confusion_matrix, '\n')
    
     # Model Accuracy, how often is the classifier correct?
    acc = metrics.accuracy_score(test_y, y_pred)
    precision = metrics.precision_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    recall = metrics.recall_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    print("Accuracy:","{:.2f}".format(acc))
    print("Precision:","{:.2f}".format(precision))
    print("Recall:","{:.2f}".format(recall), '\n')
    return y_pred_actual, y_test_actual

# %%
y_pred_actual, y_test_actual = train_test_predict(X_train_imputed, y_train, X_test_imputed, y_test, le)
# Out:
# Mean cross-validation score: 0.86
# K-fold CV average score: 0.87
#
#  Predicted        Agonist  Antagonist  Inactive  Inverse agonist
# Actual
# Agonist               84          14         0                0
# Antagonist            10         122         2                2
# Inactive               6           1        60                0
# Inverse agonist        3           9         0               11
#
# Accuracy: 0.85
# Precision: 0.86
# Recall: 0.85

# %%
pd.options.mode.chained_assignment = None

# X_test['function'] = y_test_actual
X_test['pred_function'] = y_pred_actual
X_test['entry_type'] = entry_types

X_train['entry_type'] = entry_types

# %%
X_train['entry_type'].value_counts().sort_index()
# Out:
# cross-docked active                 240
# docked inactive                     218
# experimentally determined active    247
# self-docked active                  266
# Name: entry_type, dtype: int64

# %%
# plot to show training set size
plt.rcParams["figure.figsize"] = (3,3)
plt.rcParams['figure.dpi'] = 300

values=X_train['entry_type'].value_counts(dropna=True).sort_index()
vc = X_train['entry_type'].value_counts().sort_index()
labels = vc.index

plt.pie(vc,
        labels = labels,
        autopct= lambda x: '{:.0f}'.format(x*values.sum()/100),
        colors = [colors[key] for key in labels]
       )
plt.title('Training Set')
plt.show()

# %%
X_test['entry_type'].value_counts().sort_index()
# Out:
# cross-docked active                 86
# docked inactive                     67
# experimentally determined active    95
# self-docked active                  76
# Name: entry_type, dtype: int64

# %%
# plot to show testing set size
plt.rcParams["figure.figsize"] = (3,3)
plt.rcParams['figure.dpi'] = 300

values=X_test['entry_type'].value_counts(dropna=True).sort_index()
vc = X_test['entry_type'].value_counts().sort_index()
labels = vc.index

plt.pie(vc,
        labels = labels,
        autopct= lambda x: '{:.0f}'.format(x*values.sum()/100),
        colors = [colors[key] for key in labels],
       )
plt.title('Testing Set')
plt.show()

# %%
plt.rcParams['axes.axisbelow'] = True
plt.rcParams["figure.figsize"] = (10,2)
plt.rcParams['figure.dpi'] = 150
X_test['entry_type'].hist(align='mid', bins = np.arange(5) - 0.5, rwidth = 0.2).grid(axis='x')

# %%
X_test
# Out:
#      PDBID  1.31_intenergysum  1.31_inttype1  1.31_intenergy1  1.31_inttype2  \
# 1013  5D5A                0.0              1              0.0              1
# 1282  6ZFZ                0.0              1              0.0              1
# 60    6VMS                NaN              0              NaN              0
# 974   7DHR                0.0              1              0.0              1
# 1288  6H7N                NaN              0              NaN              0
# ...    ...                ...            ...              ...            ...
# 1280  5NM4                0.0              1              0.0              1
# 638   3ODU                0.0              1              0.0              1
# 1232  6PS3                0.0              1              0.0              1
# 749   7VOE                NaN              0              NaN              0
# 887   6HLL                0.0              1              0.0              1
#
#       1.31_intenergy2  1.35_intenergysum  1.35_inttype1  1.35_intenergy1  \
# 1013              0.0                0.0              1              0.0
# 1282              0.0                0.0              1              0.0
# 60                NaN                0.0              1              0.0
# 974               0.0                0.0              1              0.0
# 1288              NaN                0.0              1              0.0
# ...               ...                ...            ...              ...
# 1280              0.0                0.0              1              0.0
# 638               0.0               -0.1              2             -0.1
# 1232              0.0                0.0              1              0.0
# 749               NaN                0.0              1              0.0
# 887               0.0                0.0              1              0.0
#
#       1.35_inttype2  ...  7.43_inttype2  7.43_intenergy2  7.46_intenergysum  \
# 1013              1  ...              3              0.0                0.0
# 1282              1  ...              3              0.0                0.0
# 60                1  ...              3              0.0                0.0
# 974               1  ...              3              0.0                0.0
# 1288              1  ...              3              0.0                0.0
# ...             ...  ...            ...              ...                ...
# 1280              1  ...              3              0.0                0.0
# 638               1  ...              1              0.0                0.0
# 1232              1  ...              1              0.0                0.0
# 749               1  ...              1              0.0                0.0
# 887               1  ...              1              0.0                0.0
#
#       7.46_inttype1  7.46_intenergy1  7.46_inttype2  7.46_intenergy2  \
# 1013              1              0.0              1              0.0
# 1282              1              0.0              1              0.0
# 60                1              0.0              1              0.0
# 974               1              0.0              1              0.0
# 1288              1              0.0              1              0.0
# ...             ...              ...            ...              ...
# 1280              1              0.0              1              0.0
# 638               1              0.0              1              0.0
# 1232              1              0.0              1              0.0
# 749               1              0.0              1              0.0
# 887               1              0.0              1              0.0
#
#            actual_fxn    pred_function                        entry_type
# 1013  Inverse agonist  Inverse agonist               cross-docked active
# 1282          Agonist          Agonist               cross-docked active
# 60            Agonist          Agonist  experimentally determined active
# 974           Agonist          Agonist                self-docked active
# 1288          Agonist          Agonist               cross-docked active
# ...               ...              ...                               ...
# 1280       Antagonist       Antagonist               cross-docked active
# 638          Inactive       Antagonist                   docked inactive
# 1232       Antagonist       Antagonist               cross-docked active
# 749           Agonist          Agonist                self-docked active
# 887        Antagonist       Antagonist                self-docked active
#
# [324 rows x 284 columns]

# %%
# get incorrect predictions in test set

entries = []
for i in range(len(X_test)):
    if X_test['actual_fxn'].iloc[i] != X_test['pred_function'].iloc[i]:
        entries.append(i)

wrong_preds_df = X_test.iloc[entries,:]

# %%
# histogram denoting which entry type is most frequently predicted incorrectly
wrong_preds_df['entry_type'].hist(align='mid', bins = np.arange(5) - 0.5, rwidth = 0.2).grid(axis='x')

# %%
# print('Entry Type\tIncorrect\tNum. Entries\tPercent Incorrect\tPercent Correct')

entry_types = []
incorrects = []
num_entries = []
percent_incorrect = []
percent_correct = []
for x in ['experimentally determined active', 'docked inactive', 'self-docked active', 'cross-docked active']:
    num_test_entries = len(X_test.loc[X_test['entry_type'] == x])
    incorrect_test_entries = len(wrong_preds_df.loc[X_test['entry_type'] == x])
    percent = (incorrect_test_entries / num_test_entries) * 100
    
    # append each value to lists to be used for df construction
    entry_types.append(x)
    incorrects.append(incorrect_test_entries)
    num_entries.append(num_test_entries)
    percent_incorrect.append("{:.2f}".format(percent))
    percent_correct.append("{:.2f}".format(100 - percent))
#     print(x, '\t', incorrect_test_entries, '\t\t', num_test_entries, '\t\t', percent, '\t', 100 - percent)

# dataframe construction/display
results_df = pd.DataFrame({
    'Entry Type': entry_types,
    'Incorrect': incorrects,
    'Num. Entries' : num_entries,
    'Percent Incorrect' : percent_incorrect,
    'Percent Correct' : percent_correct
})

display(results_df)
# Out:
#                          Entry Type  Incorrect  Num. Entries  \
# 0  experimentally determined active         18            95
# 1                   docked inactive          7            67
# 2                self-docked active          8            76
# 3               cross-docked active         14            86
#
#   Percent Incorrect Percent Correct
# 0             18.95           81.05
# 1             10.45           89.55
# 2             10.53           89.47
# 3             16.28           83.72

# %%
wrong_preds_df.loc[wrong_preds_df['entry_type'] == 'self-docked active']['actual_fxn'].value_counts()
# Out:
# Antagonist         3
# Agonist            3
# Inverse agonist    2
# Name: actual_fxn, dtype: int64

# %% [markdown]
# ## GridSearch for best RF parameters

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
params_to_test = {
    'n_estimators':[10, 100, 250, 500, 750, 1000]
}

# %%
rf_model = RandomForestClassifier(random_state=1)

grid_search = GridSearchCV(rf_model, param_grid=params_to_test, cv=10, scoring='accuracy')

grid_search.fit(X_train_imputed.iloc[:, 1:], y_train)

best_params = grid_search.best_params_ 

print(best_params)
# Out:
# {'n_estimators': 100}

# %% [markdown]
# ## XGBoost

# %%
def train_test_predict_xgboost(train_df, train_y, test_df, test_y, encoder):
    #Import Random Forest Model
    from sklearn.ensemble import RandomForestClassifier
    
    import xgboost as xgb

    xgbc = xgb.XGBClassifier(use_label_encoder=False,
                             eval_metric='mlogloss',
                             n_estimators=100,
                             random_state = 1,
                             learning_rate = 0.1
                            )


    #Train the model using the training sets y_pred=clf.predict(X_test)
    xgbc.fit(train_df.iloc[:, 1:], train_y)
    
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import cross_val_score, KFold
    import numpy as np

    # cross-validation
    scores = cross_val_score(xgbc, train_df.iloc[:, 1:], train_y, cv=5)
    print("Mean cross-validation score: %.2f" % scores.mean())

    # k-fold CV
    kfold = KFold(n_splits=10, shuffle=True, random_state = 1)
    kf_cv_scores = cross_val_score(xgbc, train_df.iloc[:, 1:], train_y, cv=kfold)
    print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
    
    # test set predictions
    y_pred = xgbc.predict(test_df.iloc[:, 1:])

    #Import scikit-learn metrics module for accuracy calculation
    from sklearn import metrics

    # reverse label encoding
    y_pred_actual = encoder.inverse_transform(y_pred)
    y_test_actual = encoder.inverse_transform(test_y)

    data = {'y_Actual':    y_test_actual,
            'y_Predicted': y_pred_actual
            }

    df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])

    confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
    print ('\n', confusion_matrix, '\n')
    
     # Model Accuracy, how often is the classifier correct?
    acc = metrics.accuracy_score(test_y, y_pred)
    precision = metrics.precision_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    recall = metrics.recall_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    print("Accuracy:","{:.2f}".format(acc))
    print("Precision:","{:.2f}".format(precision))
    print("Recall:","{:.2f}".format(recall), '\n')

# %%
train_test_predict_xgboost(X_train_imputed, y_train, X_test_imputed, y_test, encoder)
# Out:
# Mean cross-validation score: 0.85
# K-fold CV average score: 0.85
#
#  Predicted        Agonist  Antagonist  Inactive  Inverse agonist
# Actual
# Agonist               82          15         1                0
# Antagonist            10         122         3                1
# Inactive               2           2        63                0
# Inverse agonist        3           9         0               11
#
# Accuracy: 0.86
# Precision: 0.86
# Recall: 0.86

# %% [markdown]
# ## GridSearch for best XGBoost parameters

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

params_to_test = {
    'n_estimators':[10, 100, 250, 500, 750, 1000],
    'learning_rate':[0.001, 0.01, 0.1, 0.2, 0.3]
}

xgb_model = xgbc = xgb.XGBClassifier(use_label_encoder=False,
                             eval_metric='mlogloss',
                             random_state = 1,
                            )

grid_search = GridSearchCV(xgb_model, param_grid=params_to_test, cv=10, scoring='accuracy')

grid_search.fit(X_train_imputed.iloc[:, 1:], y_train)

best_params = grid_search.best_params_ 

print(best_params)
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %% [markdown]
# ## LightGBM

# %%
def train_test_predict_lgbm(train_df, train_y, test_df, test_y, encoder):
    #Import Random Forest Model
    import lightgbm as lgb
    
    # create classifier
    clf = lgb.LGBMClassifier(n_estimators = 500, random_state = 1)

    #Train the model using the training sets y_pred=clf.predict(X_test)
    clf.fit(train_df.iloc[:, 1:], train_y)
    
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import cross_val_score, KFold
    import numpy as np

    # cross-validation
    scores = cross_val_score(clf, train_df.iloc[:, 1:], train_y, cv=5)
    print("Mean cross-validation score: %.2f" % scores.mean())

    # k-fold CV
    kfold = KFold(n_splits=10, shuffle=True, random_state = 1)
    kf_cv_scores = cross_val_score(clf, train_df.iloc[:, 1:], train_y, cv=kfold)
    print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
    
    # test set predictions
    y_pred = clf.predict(test_df.iloc[:, 1:])

    #Import scikit-learn metrics module for accuracy calculation
    from sklearn import metrics

    # reverse label encoding
    y_pred_actual = encoder.inverse_transform(y_pred)
    y_test_actual = encoder.inverse_transform(test_y)

    data = {'y_Actual':    y_test_actual,
            'y_Predicted': y_pred_actual
            }

    df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])

    confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
    print ('\n', confusion_matrix, '\n')
    
     # Model Accuracy, how often is the classifier correct?
    acc = metrics.accuracy_score(test_y, y_pred)
    precision = metrics.precision_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    recall = metrics.recall_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    print("Accuracy:","{:.2f}".format(acc))
    print("Precision:","{:.2f}".format(precision))
    print("Recall:","{:.2f}".format(recall), '\n')

# %%
train_test_predict_lgbm(X_train_imputed, y_train, X_test_imputed, y_test, encoder)
# Out:
# Mean cross-validation score: 0.84
# K-fold CV average score: 0.85
#
#  Predicted        Agonist  Antagonist  Inactive  Inverse agonist
# Actual
# Agonist               86          11         1                0
# Antagonist             9         121         4                2
# Inactive               4           1        62                0
# Inverse agonist        3           8         1               11
#
# Accuracy: 0.86
# Precision: 0.86
# Recall: 0.86

# %% [markdown]
# ## GridSearch for best LightGBM parameters

# %%
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb

params_to_test = {
    'n_estimators':[10, 100, 250, 500, 750, 1000],
}

clf_model = lgb.LGBMClassifier(random_state = 1)

grid_search = GridSearchCV(clf_model, param_grid=params_to_test, cv=10, scoring='accuracy')

grid_search.fit(X_train_imputed.iloc[:, 1:], y_train)

best_params = grid_search.best_params_ 

print(best_params)
# Out:
# {'n_estimators': 500}

# %% [markdown]
# ## SVM

# %%
def train_test_predict_svm(train_df, train_y, test_df, test_y, encoder):
    from sklearn import svm

    #Create a svm Classifier
    clf = svm.SVC(kernel='rbf', tol = 1e-4) # Linear Kernel

    #Train the model using the training sets y_pred=clf.predict(X_test)
    clf.fit(train_df, train_y)
    
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import cross_val_score, KFold
    import numpy as np

    # cross-validation
    scores = cross_val_score(clf, train_df, train_y, cv=5)
    print("Mean cross-validation score: %.2f" % scores.mean())

    # k-fold CV
    kfold = KFold(n_splits=10, shuffle=True, random_state = 1)
    kf_cv_scores = cross_val_score(clf, train_df, train_y, cv=kfold)
    print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
    
    # test set predictions
    y_pred = clf.predict(test_df)

    #Import scikit-learn metrics module for accuracy calculation
    from sklearn import metrics

    # reverse label encoding
    y_pred_actual = encoder.inverse_transform(y_pred)
    y_test_actual = encoder.inverse_transform(test_y)

    data = {'y_Actual':    y_test_actual,
            'y_Predicted': y_pred_actual
            }

    df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])

    confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
    print ('\n', confusion_matrix, '\n')
    
     # Model Accuracy, how often is the classifier correct?
    acc = metrics.accuracy_score(test_y, y_pred)
    precision = metrics.precision_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    recall = metrics.recall_score(test_y, y_pred, average = 'weighted', labels=np.unique(y_pred))
    print("Accuracy:","{:.2f}".format(acc))
    print("Precision:","{:.2f}".format(precision))
    print("Recall:","{:.2f}".format(recall), '\n')

# %%
train_test_predict_svm(X_train_imputed1, y_train1, X_test_imputed1, y_test1, encoder1)
# Out:
# Mean cross-validation score: 0.81
# K-fold CV average score: 0.83
#
#  Predicted        Agonist  Antagonist  Inactive
# Actual
# Agonist               32           1         6
# Antagonist            12          32         8
# Inactive               0           1        59
# Inverse agonist        3           4         5
#
# Accuracy: 0.75
# Precision: 0.77
# Recall: 0.81
