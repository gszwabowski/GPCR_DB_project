# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Data Transformation

# %%
df = pd.read_csv('364_interaction_energies_state_function.txt', sep='\t')
df.fillna('None', inplace=True)

# %%
display(df)
# Out:
#      index PDBID         State    Function  1.21_intenergysum 1.21_inttype1  \
# 0        1  7EW2        Active     Agonist               -999          None
# 1        2  7EW3        Active     Agonist               -999          None
# 2        3  7EW4        Active     Agonist               -999          None
# 3        4  7EW1        Active     Agonist               -999          None
# 4        5  7LD4        Active     Agonist               -999          None
# ..     ...   ...           ...         ...                ...           ...
# 359    387  5C1M        Active     Agonist               -999          None
# 360    388  4EJ4      Inactive  Antagonist               -999          None
# 361    389  4DKL      Inactive  Antagonist               -999          None
# 362    390  6Z10  Intermediate  Antagonist               -999          None
# 363    391  6RNK  Intermediate  Antagonist               -999          None
#
#      1.21_intenergy1 1.21_inttype2  1.21_intenergy2  1.22_intenergysum  ...  \
# 0               -999          None             -999               -999  ...
# 1               -999          None             -999               -999  ...
# 2               -999          None             -999               -999  ...
# 3               -999          None             -999               -999  ...
# 4               -999          None             -999               -999  ...
# ..               ...           ...              ...                ...  ...
# 359             -999          None             -999               -999  ...
# 360             -999          None             -999               -999  ...
# 361             -999          None             -999               -999  ...
# 362             -999          None             -999               -999  ...
# 363             -999          None             -999               -999  ...
#
#     7.67_intenergysum  7.67_inttype1 7.67_intenergy1  7.67_inttype2  \
# 0                -999           None            -999           None
# 1                -999           None            -999           None
# 2                -999           None            -999           None
# 3                -999           None            -999           None
# 4                -999           None            -999           None
# ..                ...            ...             ...            ...
# 359              -999           None            -999           None
# 360              -999           None            -999           None
# 361              -999           None            -999           None
# 362              -999           None            -999           None
# 363              -999           None            -999           None
#
#      7.67_intenergy2 7.68_intenergysum  7.68_inttype1 7.68_intenergy1  \
# 0               -999              -999           None            -999
# 1               -999              -999           None            -999
# 2               -999              -999           None            -999
# 3               -999              -999           None            -999
# 4               -999              -999           None            -999
# ..               ...               ...            ...             ...
# 359             -999              -999           None            -999
# 360             -999              -999           None            -999
# 361             -999              -999           None            -999
# 362             -999              -999           None            -999
# 363             -999              -999           None            -999
#
#      7.68_inttype2  7.68_intenergy2
# 0             None             -999
# 1             None             -999
# 2             None             -999
# 3             None             -999
# 4             None             -999
# ..             ...              ...
# 359           None             -999
# 360           None             -999
# 361           None             -999
# 362           None             -999
# 363           None             -999
#
# [364 rows x 1664 columns]

# %%
df.to_csv('df.csv')

# %%
# get residue numbers to serve as rows for new dataframe
resnums = []
cols = [col for col in df.columns if 'sum' in col]

for col in cols:
    resnum = col[:4]
    resnums.append(resnum)
    
#print(resnums)

# %%
# get list of PDBID values, states, functions
PDBIDs = list(df['PDBID'])
states = list(df['State'])
functions = list(df['Function'])
#PDBIDs

# %%
# generate column names for new dataframe
colnames = []

for PDBID in PDBIDs:
    colnames.append(PDBID + '_state') # new 5/17
    colnames.append(PDBID + '_function') # new 5/17
    colnames.append(PDBID + '_intenergysum')
    colnames.append(PDBID + '_inttype1')
    colnames.append(PDBID + '_intenergy1')
    colnames.append(PDBID + '_inttype2')
    colnames.append(PDBID + '_intenergy2')

# %%
colnames
# Out:
# ['7EW2_state',
#  '7EW2_function',
#  '7EW2_intenergysum',
#  '7EW2_inttype1',
#  '7EW2_intenergy1',
#  '7EW2_inttype2',
#  '7EW2_intenergy2',
#  '7EW3_state',
#  '7EW3_function',
#  '7EW3_intenergysum',
#  '7EW3_inttype1',
#  '7EW3_intenergy1',
#  '7EW3_inttype2',
#  '7EW3_intenergy2',
#  '7EW4_state',
#  '7EW4_function',
#  '7EW4_intenergysum',
#  '7EW4_inttype1',
#  '7EW4_intenergy1',
#  '7EW4_inttype2',
#  '7EW4_intenergy2',
#  '7EW1_state',
#  '7EW1_function',
#  '7EW1_intenergysum',
#  '7EW1_inttype1',
#  '7EW1_intenergy1',
#  '7EW1_inttype2',
#  '7EW1_intenergy2',
#  '7LD4_state',
#  '7LD4_function',
#  '7LD4_intenergysum',
#  '7LD4_inttype1',
#  '7LD4_intenergy1',
#  '7LD4_inttype2',
#  '7LD4_intenergy2',
#  '7LD3_state',
#  '7LD3_function',
#  '7LD3_intenergysum',
#  '7LD3_inttype1',
#  '7LD3_intenergy1',
#  '7LD3_inttype2',
#  '7LD3_intenergy2',
#  '7RM5_state',
#  '7RM5_function',
#  '7RM5_intenergysum',
#  '7RM5_inttype1',
#  '7RM5_intenergy1',
#  '7RM5_inttype2',
#  '7RM5_intenergy2',
#  '7M8W_state',
#  '7M8W_function',
#  '7M8W_intenergysum',
#  '7M8W_inttype1',
#  '7M8W_intenergy1',
#  '7M8W_inttype2',
#  '7M8W_intenergy2',
#  '7DB6_state',
#  '7DB6_function',
#  '7DB6_intenergysum',
#  '7DB6_inttype1',
#  '7DB6_intenergy1',
#  '7DB6_inttype2',
#  '7DB6_intenergy2',
#  '7EXD_state',
#  '7EXD_function',
#  '7EXD_intenergysum',
#  '7EXD_inttype1',
#  '7EXD_intenergy1',
#  '7EXD_inttype2',
#  '7EXD_intenergy2',
#  '7C4S_state',
#  '7C4S_function',
#  '7C4S_intenergysum',
#  '7C4S_inttype1',
#  '7C4S_intenergy1',
#  '7C4S_inttype2',
#  '7C4S_intenergy2',
#  '7CX3_state',
#  '7CX3_function',
#  '7CX3_intenergysum',
#  '7CX3_inttype1',
#  '7CX3_intenergy1',
#  '7CX3_inttype2',
#  '7CX3_intenergy2',
#  '7CX2_state',
#  '7CX2_function',
#  '7CX2_intenergysum',
#  '7CX2_inttype1',
#  '7CX2_intenergy1',
#  '7CX2_inttype2',
#  '7CX2_intenergy2',
#  '7CX4_state',
#  '7CX4_function',
#  '7CX4_intenergysum',
#  '7CX4_inttype1',
#  '7CX4_intenergy1',
#  '7CX4_inttype2',
#  '7CX4_intenergy2',
#  '7E32_state',
#  '7E32_function',
#  '7E32_intenergysum',
#  '7E32_inttype1',
#  '7E32_intenergy1',
#  '7E32_inttype2',
#  '7E32_intenergy2',
#  '7E2Z_state',
#  '7E2Z_function',
#  '7E2Z_intenergysum',
#  '7E2Z_inttype1',
#  '7E2Z_intenergy1',
#  '7E2Z_inttype2',
#  '7E2Z_intenergy2',
#  '7E2Y_state',
#  '7E2Y_function',
#  '7E2Y_intenergysum',
#  '7E2Y_inttype1',
#  '7E2Y_intenergy1',
#  '7E2Y_inttype2',
#  '7E2Y_intenergy2',
#  '7E33_state',
#  '7E33_function',
#  '7E33_intenergysum',
#  '7E33_inttype1',
#  '7E33_intenergy1',
#  '7E33_inttype2',
#  '7E33_intenergy2',
#  '7JOZ_state',
#  '7JOZ_function',
#  '7JOZ_intenergysum',
#  '7JOZ_inttype1',
#  '7JOZ_intenergy1',
#  '7JOZ_inttype2',
#  '7JOZ_intenergy2',
#  '7ARO_state',
#  '7ARO_function',
#  '7ARO_intenergysum',
#  '7ARO_inttype1',
#  '7ARO_intenergy1',
#  '7ARO_inttype2',
#  '7ARO_intenergy2',
#  '7DFL_state',
#  '7DFL_function',
#  '7DFL_intenergysum',
#  '7DFL_inttype1',
#  '7DFL_intenergy1',
#  '7DFL_inttype2',
#  '7DFL_intenergy2',
#  '7CMV_state',
#  '7CMV_function',
#  '7CMV_intenergysum',
#  '7CMV_inttype1',
#  '7CMV_intenergy1',
#  '7CMV_inttype2',
#  '7CMV_intenergy2',
#  '7CMU_state',
#  '7CMU_function',
#  '7CMU_intenergysum',
#  '7CMU_inttype1',
#  '7CMU_intenergy1',
#  '7CMU_inttype2',
#  '7CMU_intenergy2',
#  '7CRH_state',
#  '7CRH_function',
#  '7CRH_intenergysum',
#  '7CRH_inttype1',
#  '7CRH_intenergy1',
#  '7CRH_inttype2',
#  '7CRH_intenergy2',
#  '7CKX_state',
#  '7CKX_function',
#  '7CKX_intenergysum',
#  '7CKX_inttype1',
#  '7CKX_intenergy1',
#  '7CKX_inttype2',
#  '7CKX_intenergy2',
#  '7CKW_state',
#  '7CKW_function',
#  '7CKW_intenergysum',
#  '7CKW_inttype1',
#  '7CKW_intenergy1',
#  '7CKW_inttype2',
#  '7CKW_intenergy2',
#  '7CKY_state',
#  '7CKY_function',
#  '7CKY_intenergysum',
#  '7CKY_inttype1',
#  '7CKY_intenergy1',
#  '7CKY_inttype2',
#  '7CKY_intenergy2',
#  '7JV5_state',
#  '7JV5_function',
#  '7JV5_intenergysum',
#  '7JV5_inttype1',
#  '7JV5_intenergy1',
#  '7JV5_inttype2',
#  '7JV5_intenergy2',
#  '7JVQ_state',
#  '7JVQ_function',
#  '7JVQ_intenergysum',
#  '7JVQ_inttype1',
#  '7JVQ_intenergy1',
#  '7JVQ_inttype2',
#  '7JVQ_intenergy2',
#  '7JVP_state',
#  '7JVP_function',
#  '7JVP_intenergysum',
#  '7JVP_inttype1',
#  '7JVP_intenergy1',
#  '7JVP_inttype2',
#  '7JVP_intenergy2',
#  '7JVR_state',
#  '7JVR_function',
#  '7JVR_intenergysum',
#  '7JVR_inttype1',
#  '7JVR_intenergy1',
#  '7JVR_inttype2',
#  '7JVR_intenergy2',
#  '7K15_state',
#  '7K15_function',
#  '7K15_intenergysum',
#  '7K15_inttype1',
#  '7K15_intenergy1',
#  '7K15_inttype2',
#  '7K15_intenergy2',
#  '7L1V_state',
#  '7L1V_function',
#  '7L1V_intenergysum',
#  '7L1V_inttype1',
#  '7L1V_intenergy1',
#  '7L1V_inttype2',
#  '7L1V_intenergy2',
#  '7DDZ_state',
#  '7DDZ_function',
#  '7DDZ_intenergysum',
#  '7DDZ_inttype1',
#  '7DDZ_intenergy1',
#  '7DDZ_inttype2',
#  '7DDZ_intenergy2',
#  '7DFP_state',
#  '7DFP_function',
#  '7DFP_intenergysum',
#  '7DFP_inttype1',
#  '7DFP_intenergy1',
#  '7DFP_inttype2',
#  '7DFP_intenergy2',
#  '7DHI_state',
#  '7DHI_function',
#  '7DHI_intenergysum',
#  '7DHI_inttype1',
#  '7DHI_intenergy1',
#  '7DHI_inttype2',
#  '7DHI_intenergy2',
#  '7DHR_state',
#  '7DHR_function',
#  '7DHR_intenergysum',
#  '7DHR_inttype1',
#  '7DHR_intenergy1',
#  '7DHR_inttype2',
#  '7DHR_intenergy2',
#  '7BU7_state',
#  '7BU7_function',
#  '7BU7_intenergysum',
#  '7BU7_inttype1',
#  '7BU7_intenergy1',
#  '7BU7_inttype2',
#  '7BU7_intenergy2',
#  '7BU6_state',
#  '7BU6_function',
#  '7BU6_intenergysum',
#  '7BU6_inttype1',
#  '7BU6_intenergy1',
#  '7BU6_inttype2',
#  '7BU6_intenergy2',
#  '7BVQ_state',
#  '7BVQ_function',
#  '7BVQ_intenergysum',
#  '7BVQ_inttype1',
#  '7BVQ_intenergy1',
#  '7BVQ_inttype2',
#  '7BVQ_intenergy2',
#  '7BTS_state',
#  '7BTS_function',
#  '7BTS_intenergysum',
#  '7BTS_inttype1',
#  '7BTS_intenergy1',
#  '7BTS_inttype2',
#  '7BTS_intenergy2',
#  '6LPJ_state',
#  '6LPJ_function',
#  '6LPJ_intenergysum',
#  '6LPJ_inttype1',
#  '6LPJ_intenergy1',
#  '6LPJ_inttype2',
#  '6LPJ_intenergy2',
#  '6LPL_state',
#  '6LPL_function',
#  '6LPL_intenergysum',
#  '6LPL_inttype1',
#  '6LPL_intenergy1',
#  '6LPL_inttype2',
#  '6LPL_intenergy2',
#  '6LPK_state',
#  '6LPK_function',
#  '6LPK_intenergysum',
#  '6LPK_inttype1',
#  '6LPK_intenergy1',
#  '6LPK_inttype2',
#  '6LPK_intenergy2',
#  '6WQA_state',
#  '6WQA_function',
#  '6WQA_intenergysum',
#  '6WQA_inttype1',
#  '6WQA_intenergy1',
#  '6WQA_inttype2',
#  '6WQA_intenergy2',
#  '7D7M_state',
#  '7D7M_function',
#  '7D7M_intenergysum',
#  '7D7M_inttype1',
#  '7D7M_intenergy1',
#  '7D7M_inttype2',
#  '7D7M_intenergy2',
#  '7BR3_state',
#  '7BR3_function',
#  '7BR3_intenergysum',
#  '7BR3_inttype1',
#  '7BR3_intenergy1',
#  '7BR3_inttype2',
#  '7BR3_intenergy2',
#  '6WHA_state',
#  '6WHA_function',
#  '6WHA_intenergysum',
#  '6WHA_inttype1',
#  '6WHA_intenergy1',
#  '6WHA_inttype2',
#  '6WHA_intenergy2',
#  '6WH4_state',
#  '6WH4_function',
#  '6WH4_intenergysum',
#  '6WH4_inttype1',
#  '6WH4_intenergy1',
#  '6WH4_inttype2',
#  '6WH4_intenergy2',
#  '6WGT_state',
#  '6WGT_function',
#  '6WGT_intenergysum',
#  '6WGT_inttype1',
#  '6WGT_intenergy1',
#  '6WGT_inttype2',
#  '6WGT_intenergy2',
#  '6ZDR_state',
#  '6ZDR_function',
#  '6ZDR_intenergysum',
#  '6ZDR_inttype1',
#  '6ZDR_intenergy1',
#  '6ZDR_inttype2',
#  '6ZDR_intenergy2',
#  '6ZDV_state',
#  '6ZDV_function',
#  '6ZDV_intenergysum',
#  '6ZDV_inttype1',
#  '6ZDV_intenergy1',
#  '6ZDV_inttype2',
#  '6ZDV_intenergy2',
#  '7CFM_state',
#  '7CFM_function',
#  '7CFM_intenergysum',
#  '7CFM_inttype1',
#  '7CFM_intenergy1',
#  '7CFM_inttype2',
#  '7CFM_intenergy2',
#  '6KO5_state',
#  '6KO5_function',
#  '6KO5_intenergysum',
#  '6KO5_inttype1',
#  '6KO5_intenergy1',
#  '6KO5_inttype2',
#  '6KO5_intenergy2',
#  '7BZ2_state',
#  '7BZ2_function',
#  '7BZ2_intenergysum',
#  '7BZ2_inttype1',
#  '7BZ2_intenergy1',
#  '7BZ2_inttype2',
#  '7BZ2_intenergy2',
#  '6TPK_state',
#  '6TPK_function',
#  '6TPK_intenergysum',
#  '6TPK_inttype1',
#  '6TPK_intenergy1',
#  '6TPK_inttype2',
#  '6TPK_intenergy2',
#  '7C61_state',
#  '7C61_function',
#  '7C61_intenergysum',
#  '7C61_inttype1',
#  '7C61_intenergy1',
#  '7C61_inttype2',
#  '7C61_intenergy2',
#  '6S0L_state',
#  '6S0L_function',
#  '6S0L_intenergysum',
#  '6S0L_inttype1',
#  '6S0L_intenergy1',
#  '6S0L_inttype2',
#  '6S0L_intenergy2',
#  '6S0Q_state',
#  '6S0Q_function',
#  '6S0Q_intenergysum',
#  '6S0Q_inttype1',
#  '6S0Q_intenergy1',
#  '6S0Q_inttype2',
#  '6S0Q_intenergy2',
#  '6V9S_state',
#  '6V9S_function',
#  '6V9S_intenergysum',
#  '6V9S_inttype1',
#  '6V9S_intenergy1',
#  '6V9S_inttype2',
#  '6V9S_intenergy2',
#  '6VMS_state',
#  '6VMS_function',
#  '6VMS_intenergysum',
#  '6VMS_inttype1',
#  '6VMS_intenergy1',
#  '6VMS_inttype2',
#  '6VMS_intenergy2',
#  '6K41_state',
#  '6K41_function',
#  '6K41_intenergysum',
#  '6K41_inttype1',
#  '6K41_intenergy1',
#  '6K41_inttype2',
#  '6K41_intenergy2',
#  '6K42_state',
#  '6K42_function',
#  '6K42_intenergysum',
#  '6K42_inttype1',
#  '6K42_intenergy1',
#  '6K42_inttype2',
#  '6K42_intenergy2',
#  '6VI4_state',
#  '6VI4_function',
#  '6VI4_intenergysum',
#  '6VI4_inttype1',
#  '6VI4_intenergy1',
#  '6VI4_inttype2',
#  '6VI4_intenergy2',
#  '6LUQ_state',
#  '6LUQ_function',
#  '6LUQ_intenergysum',
#  '6LUQ_inttype1',
#  '6LUQ_intenergy1',
#  '6LUQ_inttype2',
#  '6LUQ_intenergy2',
#  '6U1N_state',
#  '6U1N_function',
#  '6U1N_intenergysum',
#  '6U1N_inttype1',
#  '6U1N_intenergy1',
#  '6U1N_inttype2',
#  '6U1N_intenergy2',
#  '6LI0_state',
#  '6LI0_function',
#  '6LI0_intenergysum',
#  '6LI0_inttype1',
#  '6LI0_intenergy1',
#  '6LI0_inttype2',
#  '6LI0_intenergy2',
#  '6KPG_state',
#  '6KPG_function',
#  '6KPG_intenergysum',
#  '6KPG_inttype1',
#  '6KPG_intenergy1',
#  '6KPG_inttype2',
#  '6KPG_intenergy2',
#  '6PT0_state',
#  '6PT0_function',
#  '6PT0_intenergysum',
#  '6PT0_inttype1',
#  '6PT0_intenergy1',
#  '6PT0_inttype2',
#  '6PT0_intenergy2',
#  '6KPF_state',
#  '6KPF_function',
#  '6KPF_intenergysum',
#  '6KPF_inttype1',
#  '6KPF_intenergy1',
#  '6KPF_inttype2',
#  '6KPF_intenergy2',
#  '6KPC_state',
#  '6KPC_function',
#  '6KPC_intenergysum',
#  '6KPC_inttype1',
#  '6KPC_intenergy1',
#  '6KPC_inttype2',
#  '6KPC_intenergy2',
#  '6TOT_state',
#  '6TOT_function',
#  '6TOT_intenergysum',
#  '6TOT_inttype1',
#  '6TOT_intenergy1',
#  '6TOT_inttype2',
#  '6TOT_intenergy2',
#  '6TOS_state',
#  '6TOS_function',
#  '6TOS_intenergysum',
#  '6TOS_inttype1',
#  '6TOS_intenergy1',
#  '6TOS_inttype2',
#  '6TOS_intenergy2',
#  '6TQ9_state',
#  '6TQ9_function',
#  '6TQ9_intenergysum',
#  '6TQ9_inttype1',
#  '6TQ9_intenergy1',
#  '6TQ9_inttype2',
#  '6TQ9_intenergy2',
#  '6TP6_state',
#  '6TP6_function',
#  '6TP6_intenergysum',
#  '6TP6_inttype1',
#  '6TP6_intenergy1',
#  '6TP6_inttype2',
#  '6TP6_intenergy2',
#  '6TQ6_state',
#  '6TQ6_function',
#  '6TQ6_intenergysum',
#  '6TQ6_inttype1',
#  '6TQ6_intenergy1',
#  '6TQ6_inttype2',
#  '6TQ6_intenergy2',
#  '6TQ4_state',
#  '6TQ4_function',
#  '6TQ4_intenergysum',
#  '6TQ4_inttype1',
#  '6TQ4_intenergy1',
#  '6TQ4_inttype2',
#  '6TQ4_intenergy2',
#  '6TOD_state',
#  '6TOD_function',
#  '6TOD_intenergysum',
#  '6TOD_inttype1',
#  '6TOD_intenergy1',
#  '6TOD_inttype2',
#  '6TOD_intenergy2',
#  '6TP3_state',
#  '6TP3_function',
#  '6TP3_intenergysum',
#  '6TP3_inttype1',
#  '6TP3_intenergy1',
#  '6TP3_inttype2',
#  '6TP3_intenergy2',
#  '6TP4_state',
#  '6TP4_function',
#  '6TP4_intenergysum',
#  '6TP4_inttype1',
#  '6TP4_intenergy1',
#  '6TP4_inttype2',
#  '6TP4_intenergy2',
#  '6TQ7_state',
#  '6TQ7_function',
#  '6TQ7_intenergysum',
#  '6TQ7_inttype1',
#  '6TQ7_intenergy1',
#  '6TQ7_inttype2',
#  '6TQ7_intenergy2',
#  '6TO7_state',
#  '6TO7_function',
#  '6TO7_intenergysum',
#  '6TO7_inttype1',
#  '6TO7_intenergy1',
#  '6TO7_inttype2',
#  '6TO7_intenergy2',
#  '6TPG_state',
#  '6TPG_function',
#  '6TPG_intenergysum',
#  '6TPG_inttype1',
#  '6TPG_intenergy1',
#  '6TPG_inttype2',
#  '6TPG_intenergy2',
#  '6TPN_state',
#  '6TPN_function',
#  '6TPN_intenergysum',
#  '6TPN_inttype1',
#  '6TPN_intenergy1',
#  '6TPN_inttype2',
#  '6TPN_intenergy2',
#  '6TPJ_state',
#  '6TPJ_function',
#  '6TPJ_intenergysum',
#  '6TPJ_inttype1',
#  '6TPJ_intenergy1',
#  '6TPJ_inttype2',
#  '6TPJ_intenergy2',
#  '6OL9_state',
#  '6OL9_function',
#  '6OL9_intenergysum',
#  '6OL9_inttype1',
#  '6OL9_intenergy1',
#  '6OL9_inttype2',
#  '6OL9_intenergy2',
#  '6RZ8_state',
#  '6RZ8_function',
#  '6RZ8_intenergysum',
#  '6RZ8_inttype1',
#  '6RZ8_intenergy1',
#  '6RZ8_inttype2',
#  '6RZ8_intenergy2',
#  '6RZ6_state',
#  '6RZ6_function',
#  '6RZ6_intenergysum',
#  '6RZ6_inttype1',
#  '6RZ6_intenergy1',
#  '6RZ6_inttype2',
#  '6RZ6_intenergy2',
#  '6RZ9_state',
#  '6RZ9_function',
#  '6RZ9_intenergysum',
#  '6RZ9_inttype1',
#  '6RZ9_intenergy1',
#  '6RZ9_inttype2',
#  '6RZ9_intenergy2',
#  '6RZ7_state',
#  '6RZ7_function',
#  '6RZ7_intenergysum',
#  '6RZ7_inttype1',
#  '6RZ7_intenergy1',
#  '6RZ7_inttype2',
#  '6RZ7_intenergy2',
#  '6PT3_state',
#  '6PT3_function',
#  '6PT3_intenergysum',
#  '6PT3_inttype1',
#  '6PT3_intenergy1',
#  '6PT3_inttype2',
#  '6PT3_intenergy2',
#  '6KUX_state',
#  '6KUX_function',
#  '6KUX_intenergysum',
#  '6KUX_inttype1',
#  '6KUX_intenergy1',
#  '6KUX_inttype2',
#  '6KUX_intenergy2',
#  '6KUY_state',
#  '6KUY_function',
#  '6KUY_intenergysum',
#  '6KUY_inttype1',
#  '6KUY_intenergy1',
#  '6KUY_inttype2',
#  '6KUY_intenergy2',
#  '6KUW_state',
#  '6KUW_function',
#  '6KUW_intenergysum',
#  '6KUW_inttype1',
#  '6KUW_intenergy1',
#  '6KUW_inttype2',
#  '6KUW_intenergy2',
#  '6NI3_state',
#  '6NI3_function',
#  '6NI3_intenergysum',
#  '6NI3_inttype1',
#  '6NI3_intenergy1',
#  '6NI3_inttype2',
#  '6NI3_intenergy2',
#  '6PS7_state',
#  '6PS7_function',
#  '6PS7_intenergysum',
#  '6PS7_inttype1',
#  '6PS7_intenergy1',
#  '6PS7_inttype2',
#  '6PS7_intenergy2',
#  '6PRZ_state',
#  '6PRZ_function',
#  '6PRZ_intenergysum',
#  '6PRZ_inttype1',
#  '6PRZ_intenergy1',
#  '6PRZ_inttype2',
#  '6PRZ_intenergy2',
#  '6PS1_state',
#  '6PS1_function',
#  '6PS1_intenergysum',
#  '6PS1_inttype1',
#  '6PS1_intenergy1',
#  '6PS1_inttype2',
#  '6PS1_intenergy2',
#  '6PS2_state',
#  '6PS2_function',
#  '6PS2_intenergysum',
#  '6PS2_inttype1',
#  '6PS2_intenergy1',
#  '6PS2_inttype2',
#  '6PS2_intenergy2',
#  '6PS4_state',
#  '6PS4_function',
#  '6PS4_intenergysum',
#  '6PS4_inttype1',
#  '6PS4_intenergy1',
#  '6PS4_inttype2',
#  '6PS4_intenergy2',
#  '6PS6_state',
#  '6PS6_function',
#  '6PS6_intenergysum',
#  '6PS6_inttype1',
#  '6PS6_intenergy1',
#  '6PS6_inttype2',
#  '6PS6_intenergy2',
#  '6PS0_state',
#  '6PS0_function',
#  '6PS0_intenergysum',
#  '6PS0_inttype1',
#  '6PS0_intenergy1',
#  '6PS0_inttype2',
#  '6PS0_intenergy2',
#  '6PS5_state',
#  '6PS5_function',
#  '6PS5_intenergysum',
#  '6PS5_inttype1',
#  '6PS5_intenergy1',
#  '6PS5_inttype2',
#  '6PS5_intenergy2',
#  '6PS3_state',
#  '6PS3_function',
#  '6PS3_intenergysum',
#  '6PS3_inttype1',
#  '6PS3_intenergy1',
#  '6PS3_inttype2',
#  '6PS3_intenergy2',
#  '6PS8_state',
#  '6PS8_function',
#  '6PS8_intenergysum',
#  '6PS8_inttype1',
#  '6PS8_intenergy1',
#  '6PS8_inttype2',
#  '6PS8_intenergy2',
#  '6JZH_state',
#  '6JZH_function',
#  '6JZH_intenergysum',
#  '6JZH_inttype1',
#  '6JZH_intenergy1',
#  '6JZH_inttype2',
#  '6JZH_intenergy2',
#  '6RZ4_state',
#  '6RZ4_function',
#  '6RZ4_intenergysum',
#  '6RZ4_inttype1',
#  '6RZ4_intenergy1',
#  '6RZ4_inttype2',
#  '6RZ4_intenergy2',
#  '6RZ5_state',
#  '6RZ5_function',
#  '6RZ5_intenergysum',
#  '6RZ5_inttype1',
#  '6RZ5_intenergy1',
#  '6RZ5_inttype2',
#  '6RZ5_intenergy2',
#  '6K1Q_state',
#  '6K1Q_function',
#  '6K1Q_intenergysum',
#  '6K1Q_inttype1',
#  '6K1Q_intenergy1',
#  '6K1Q_inttype2',
#  '6K1Q_intenergy2',
#  '6GT3_state',
#  '6GT3_function',
#  '6GT3_intenergysum',
#  '6GT3_inttype1',
#  '6GT3_intenergy1',
#  '6GT3_inttype2',
#  '6GT3_intenergy2',
#  '6E67_state',
#  '6E67_function',
#  '6E67_intenergysum',
#  '6E67_inttype1',
#  '6E67_intenergy1',
#  '6E67_inttype2',
#  '6E67_intenergy2',
#  '6OIJ_state',
#  '6OIJ_function',
#  '6OIJ_intenergysum',
#  '6OIJ_inttype1',
#  '6OIJ_intenergy1',
#  '6OIJ_inttype2',
#  '6OIJ_intenergy2',
#  '6MH8_state',
#  '6MH8_function',
#  '6MH8_intenergysum',
#  '6MH8_inttype1',
#  '6MH8_intenergy1',
#  '6MH8_inttype2',
#  '6MH8_intenergy2',
#  '6ME2_state',
#  '6ME2_function',
#  '6ME2_intenergysum',
#  '6ME2_inttype1',
#  '6ME2_intenergy1',
#  '6ME2_inttype2',
#  '6ME2_intenergy2',
#  '6ME3_state',
#  '6ME3_function',
#  '6ME3_intenergysum',
#  '6ME3_inttype1',
#  '6ME3_intenergy1',
#  '6ME3_inttype2',
#  '6ME3_intenergy2',
#  '6ME4_state',
#  '6ME4_function',
#  '6ME4_intenergysum',
#  '6ME4_inttype1',
#  '6ME4_intenergy1',
#  '6ME4_inttype2',
#  '6ME4_intenergy2',
#  '6ME5_state',
#  '6ME5_function',
#  '6ME5_intenergysum',
#  '6ME5_inttype1',
#  '6ME5_intenergy1',
#  '6ME5_inttype2',
#  '6ME5_intenergy2',
#  '6ME9_state',
#  '6ME9_function',
#  '6ME9_intenergysum',
#  '6ME9_inttype1',
#  '6ME9_intenergy1',
#  '6ME9_inttype2',
#  '6ME9_intenergy2',
#  '6ME7_state',
#  '6ME7_function',
#  '6ME7_intenergysum',
#  '6ME7_inttype1',
#  '6ME7_intenergy1',
#  '6ME7_inttype2',
#  '6ME7_intenergy2',
#  '6ME8_state',
#  '6ME8_function',
#  '6ME8_intenergysum',
#  '6ME8_inttype1',
#  '6ME8_intenergy1',
#  '6ME8_inttype2',
#  '6ME8_intenergy2',
#  '6ME6_state',
#  '6ME6_function',
#  '6ME6_intenergysum',
#  '6ME6_inttype1',
#  '6ME6_intenergy1',
#  '6ME6_inttype2',
#  '6ME6_intenergy2',
#  '6J20_state',
#  '6J20_function',
#  '6J20_intenergysum',
#  '6J20_inttype1',
#  '6J20_intenergy1',
#  '6J20_inttype2',
#  '6J20_intenergy2',
#  '6J21_state',
#  '6J21_function',
#  '6J21_intenergysum',
#  '6J21_inttype1',
#  '6J21_intenergy1',
#  '6J21_inttype2',
#  '6J21_intenergy2',
#  '6A94_state',
#  '6A94_function',
#  '6A94_intenergysum',
#  '6A94_inttype1',
#  '6A94_intenergy1',
#  '6A94_inttype2',
#  '6A94_intenergy2',
#  '6A93_state',
#  '6A93_function',
#  '6A93_intenergysum',
#  '6A93_inttype1',
#  '6A93_intenergy1',
#  '6A93_inttype2',
#  '6A93_intenergy2',
#  '6N4B_state',
#  '6N4B_function',
#  '6N4B_intenergysum',
#  '6N4B_inttype1',
#  '6N4B_intenergy1',
#  '6N4B_inttype2',
#  '6N4B_intenergy2',
#  '5ZTY_state',
#  '5ZTY_function',
#  '5ZTY_intenergysum',
#  '5ZTY_inttype1',
#  '5ZTY_intenergy1',
#  '5ZTY_inttype2',
#  '5ZTY_intenergy2',
#  '6HLL_state',
#  '6HLL_function',
#  '6HLL_intenergysum',
#  '6HLL_inttype1',
#  '6HLL_intenergy1',
#  '6HLL_inttype2',
#  '6HLL_intenergy2',
#  '6HLP_state',
#  '6HLP_function',
#  '6HLP_intenergysum',
#  '6HLP_inttype1',
#  '6HLP_intenergy1',
#  '6HLP_inttype2',
#  '6HLP_intenergy2',
#  '6HLO_state',
#  '6HLO_function',
#  '6HLO_intenergysum',
#  '6HLO_inttype1',
#  '6HLO_intenergy1',
#  '6HLO_inttype2',
#  '6HLO_intenergy2',
#  '6GPS_state',
#  '6GPS_function',
#  '6GPS_intenergysum',
#  '6GPS_inttype1',
#  '6GPS_intenergy1',
#  '6GPS_inttype2',
#  '6GPS_intenergy2',
#  '6GPX_state',
#  '6GPX_function',
#  '6GPX_intenergysum',
#  '6GPX_inttype1',
#  '6GPX_intenergy1',
#  '6GPX_inttype2',
#  '6GPX_intenergy2',
#  '6IIU_state',
#  '6IIU_function',
#  '6IIU_intenergysum',
#  '6IIU_inttype1',
#  '6IIU_intenergy1',
#  '6IIU_inttype2',
#  '6IIU_intenergy2',
#  '6IIV_state',
#  '6IIV_function',
#  '6IIV_intenergysum',
#  '6IIV_inttype1',
#  '6IIV_intenergy1',
#  '6IIV_inttype2',
#  '6IIV_intenergy2',
#  '6E+59_state',
#  '6E+59_function',
#  '6E+59_intenergysum',
#  '6E+59_inttype1',
#  '6E+59_intenergy1',
#  '6E+59_inttype2',
#  '6E+59_intenergy2',
#  '6AK3_state',
#  '6AK3_function',
#  '6AK3_intenergysum',
#  '6AK3_inttype1',
#  '6AK3_intenergy1',
#  '6AK3_inttype2',
#  '6AK3_intenergy2',
#  '6M9T_state',
#  '6M9T_function',
#  '6M9T_intenergysum',
#  '6M9T_inttype1',
#  '6M9T_intenergy1',
#  '6M9T_inttype2',
#  '6M9T_intenergy2',
#  '5YHL_state',
#  '5YHL_function',
#  '5YHL_intenergysum',
#  '5YHL_inttype1',
#  '5YHL_intenergy1',
#  '5YHL_inttype2',
#  '5YHL_intenergy2',
#  '5YWY_state',
#  '5YWY_function',
#  '5YWY_intenergysum',
#  '5YWY_inttype1',
#  '5YWY_intenergy1',
#  '5YWY_inttype2',
#  '5YWY_intenergy2',
#  '5ZK3_state',
#  '5ZK3_function',
#  '5ZK3_intenergysum',
#  '5ZK3_inttype1',
#  '5ZK3_intenergy1',
#  '5ZK3_inttype2',
#  '5ZK3_intenergy2',
#  '5ZKB_state',
#  '5ZKB_function',
#  '5ZKB_intenergysum',
#  '5ZKB_inttype1',
#  '5ZKB_intenergy1',
#  '5ZKB_inttype2',
#  '5ZKB_intenergy2',
#  '5YC8_state',
#  '5YC8_function',
#  '5YC8_intenergysum',
#  '5YC8_inttype1',
#  '5YC8_intenergy1',
#  '5YC8_inttype2',
#  '5YC8_intenergy2',
#  '5ZKC_state',
#  '5ZKC_function',
#  '5ZKC_intenergysum',
#  '5ZKC_inttype1',
#  '5ZKC_intenergy1',
#  '5ZKC_inttype2',
#  ...]

# %%
# create empty dataframe to fill with values from df
ml_df = pd.DataFrame()
ml_df['residue'] = resnums

for colname in colnames:
    temp_df = pd.DataFrame(columns = [colname])
    pd.concat((ml_df, temp_df), axis = 1)
    ml_df[colname] = 'NA'
# Out:
# C:\Users\babow\AppData\Local\Temp/ipykernel_16000/935447373.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   ml_df[colname] = 'NA'

# %%
ml_df = ml_df.copy()
import pickle
ml_df.to_pickle('ml_df_empty.pkl')

# %%
ml_df = pd.read_pickle('ml_df_empty.pkl')
display(ml_df)
# Out:
#     residue 7EW2_state 7EW2_function 7EW2_intenergysum 7EW2_inttype1  \
# 0      1.21         NA            NA                NA            NA
# 1      1.22         NA            NA                NA            NA
# 2      1.23         NA            NA                NA            NA
# 3      1.24         NA            NA                NA            NA
# 4      1.25         NA            NA                NA            NA
# ..      ...        ...           ...               ...           ...
# 327    7.64         NA            NA                NA            NA
# 328    7.65         NA            NA                NA            NA
# 329    7.66         NA            NA                NA            NA
# 330    7.67         NA            NA                NA            NA
# 331    7.68         NA            NA                NA            NA
#
#     7EW2_intenergy1 7EW2_inttype2 7EW2_intenergy2 7EW3_state 7EW3_function  \
# 0                NA            NA              NA         NA            NA
# 1                NA            NA              NA         NA            NA
# 2                NA            NA              NA         NA            NA
# 3                NA            NA              NA         NA            NA
# 4                NA            NA              NA         NA            NA
# ..              ...           ...             ...        ...           ...
# 327              NA            NA              NA         NA            NA
# 328              NA            NA              NA         NA            NA
# 329              NA            NA              NA         NA            NA
# 330              NA            NA              NA         NA            NA
# 331              NA            NA              NA         NA            NA
#
#      ... 6Z10_intenergy1 6Z10_inttype2 6Z10_intenergy2 6RNK_state  \
# 0    ...              NA            NA              NA         NA
# 1    ...              NA            NA              NA         NA
# 2    ...              NA            NA              NA         NA
# 3    ...              NA            NA              NA         NA
# 4    ...              NA            NA              NA         NA
# ..   ...             ...           ...             ...        ...
# 327  ...              NA            NA              NA         NA
# 328  ...              NA            NA              NA         NA
# 329  ...              NA            NA              NA         NA
# 330  ...              NA            NA              NA         NA
# 331  ...              NA            NA              NA         NA
#
#     6RNK_function 6RNK_intenergysum 6RNK_inttype1 6RNK_intenergy1  \
# 0              NA                NA            NA              NA
# 1              NA                NA            NA              NA
# 2              NA                NA            NA              NA
# 3              NA                NA            NA              NA
# 4              NA                NA            NA              NA
# ..            ...               ...           ...             ...
# 327            NA                NA            NA              NA
# 328            NA                NA            NA              NA
# 329            NA                NA            NA              NA
# 330            NA                NA            NA              NA
# 331            NA                NA            NA              NA
#
#     6RNK_inttype2 6RNK_intenergy2
# 0              NA              NA
# 1              NA              NA
# 2              NA              NA
# 3              NA              NA
# 4              NA              NA
# ..            ...             ...
# 327            NA              NA
# 328            NA              NA
# 329            NA              NA
# 330            NA              NA
# 331            NA              NA
#
# [332 rows x 2549 columns]

# %%
# for df_row in range(len(df)): # row represents df rows
#     # convert row to a flattened list, dropping the first 4 columns
#     row_values = df.loc[df_row, :].values.tolist()[4:]
    
#     row_idx = 0 # row index
#     col_idx = (df_row * 5) + 1 # start at col 1 for 1st entry, col 6 for 2nd entry, etc.
#     col_end_idx = (df_row * 5) + 5
    
#     for value in row_values:
#         if col_idx > col_end_idx:
#             row_idx += 1 # start on next row in ml_df
#             col_idx = (df_row * 5) + 1 # reset column numbering
#         ml_df.at[row_idx, ml_df.columns[col_idx]] = value # write new value to column col_idx of next row
#         col_idx += 1

# %%
for df_row in range(len(df)): # row represents df rows
    # get state and ligand function from the row, assign to separate variables
    state = df.loc[df_row, :].values.tolist()[2]
    function = df.loc[df_row, :].values.tolist()[3]
    
    # get state and function columns for each row
    
    # convert row to a flattened list, dropping the first 4 columns
    row_values = df.loc[df_row, :].values.tolist()[4:]
    # print(row_values, '\n')
    
    row_idx = 0 # row index
    col_idx = (df_row * 7) + 3 # start at col 1 for 1st entry, col 8 for 2nd entry, etc.
    col_end_idx = (df_row * 7) + 7
    
    for value in row_values:
        if col_idx > col_end_idx:
            row_idx += 1 # start on next row in ml_df
            col_idx = (df_row * 7) + 3 # reset column numbering
        ml_df.at[row_idx, ml_df.columns[col_idx]] = value # write new value to column col_idx of next row
        col_idx += 1

# fill in state/function columns for each PDBID
for PDBid in PDBIDs:
    state_col = PDBid + '_state'
    function_col = PDBid + '_function'
    
    ml_df.loc[:, state_col] = states[PDBIDs.index(PDBid)]
    ml_df.loc[:, function_col] = functions[PDBIDs.index(PDBid)]

# %%
display(ml_df)
# Out:
#     residue 7EW2_state 7EW2_function 7EW2_intenergysum 7EW2_inttype1  \
# 0      1.21     Active       Agonist              -999          None
# 1      1.22     Active       Agonist              -999          None
# 2      1.23     Active       Agonist              -999          None
# 3      1.24     Active       Agonist              -999          None
# 4      1.25     Active       Agonist              -999          None
# ..      ...        ...           ...               ...           ...
# 327    7.64     Active       Agonist              -999          None
# 328    7.65     Active       Agonist              -999          None
# 329    7.66     Active       Agonist              -999          None
# 330    7.67     Active       Agonist              -999          None
# 331    7.68     Active       Agonist              -999          None
#
#     7EW2_intenergy1 7EW2_inttype2 7EW2_intenergy2 7EW3_state 7EW3_function  \
# 0              -999          None            -999     Active       Agonist
# 1              -999          None            -999     Active       Agonist
# 2              -999          None            -999     Active       Agonist
# 3              -999          None            -999     Active       Agonist
# 4              -999          None            -999     Active       Agonist
# ..              ...           ...             ...        ...           ...
# 327            -999          None            -999     Active       Agonist
# 328            -999          None            -999     Active       Agonist
# 329            -999          None            -999     Active       Agonist
# 330            -999          None            -999     Active       Agonist
# 331            -999          None            -999     Active       Agonist
#
#      ... 6Z10_intenergy1 6Z10_inttype2 6Z10_intenergy2    6RNK_state  \
# 0    ...            -999          None            -999  Intermediate
# 1    ...            -999          None            -999  Intermediate
# 2    ...            -999          None            -999  Intermediate
# 3    ...            -999          None            -999  Intermediate
# 4    ...            -999          None            -999  Intermediate
# ..   ...             ...           ...             ...           ...
# 327  ...            -999          None            -999  Intermediate
# 328  ...            -999          None            -999  Intermediate
# 329  ...            -999          None            -999  Intermediate
# 330  ...            -999          None            -999  Intermediate
# 331  ...            -999          None            -999  Intermediate
#
#     6RNK_function 6RNK_intenergysum 6RNK_inttype1 6RNK_intenergy1  \
# 0      Antagonist              -999          None            -999
# 1      Antagonist              -999          None            -999
# 2      Antagonist              -999          None            -999
# 3      Antagonist              -999          None            -999
# 4      Antagonist              -999          None            -999
# ..            ...               ...           ...             ...
# 327    Antagonist              -999          None            -999
# 328    Antagonist              -999          None            -999
# 329    Antagonist              -999          None            -999
# 330    Antagonist              -999          None            -999
# 331    Antagonist              -999          None            -999
#
#     6RNK_inttype2 6RNK_intenergy2
# 0            None            -999
# 1            None            -999
# 2            None            -999
# 3            None            -999
# 4            None            -999
# ..            ...             ...
# 327          None            -999
# 328          None            -999
# 329          None            -999
# 330          None            -999
# 331          None            -999
#
# [332 rows x 2549 columns]

# %%
# get unique interaction types
cols = [col for col in df.columns if 'type' in col]
int_types = []

for col in cols:
    for int_type in list(df[col].unique()):
        if int_type not in int_types:
            int_types.append(int_type)
            
print(int_types)
# Out:
# ['None', 'Hbond', 'Arene', 'Ionic', 'Covalent']

# %%
# encode interaction types as integers
# create instance of labelencoder
labelencoder = LabelEncoder()

# get columns with 'type' in their name
cols = [col for col in ml_df.columns if 'type' in col]

# loop though all columns and convert strings to categorical integer variables
for col in cols:
    ml_df[col] = labelencoder.fit_transform(ml_df[col])

    
# encode states as integers
# get columns with 'type' in their name
cols = [col for col in ml_df.columns if 'state' in col]

# loop though all columns and convert strings to categorical integer variables
for col in cols:
    ml_df[col] = labelencoder.fit_transform(ml_df[col])
    
# encode functions as integers
# get columns with 'type' in their name
cols = [col for col in ml_df.columns if 'function' in col]

# loop though all columns and convert strings to categorical integer variables
for col in cols:
    ml_df[col] = labelencoder.fit_transform(ml_df[col])

# %%
display(ml_df)
# Out:
#     residue  7EW2_state  7EW2_function 7EW2_intenergysum  7EW2_inttype1  \
# 0      1.21           0              0              -999              3
# 1      1.22           0              0              -999              3
# 2      1.23           0              0              -999              3
# 3      1.24           0              0              -999              3
# 4      1.25           0              0              -999              3
# ..      ...         ...            ...               ...            ...
# 327    7.64           0              0              -999              3
# 328    7.65           0              0              -999              3
# 329    7.66           0              0              -999              3
# 330    7.67           0              0              -999              3
# 331    7.68           0              0              -999              3
#
#     7EW2_intenergy1  7EW2_inttype2 7EW2_intenergy2  7EW3_state  7EW3_function  \
# 0              -999              2            -999           0              0
# 1              -999              2            -999           0              0
# 2              -999              2            -999           0              0
# 3              -999              2            -999           0              0
# 4              -999              2            -999           0              0
# ..              ...            ...             ...         ...            ...
# 327            -999              2            -999           0              0
# 328            -999              2            -999           0              0
# 329            -999              2            -999           0              0
# 330            -999              2            -999           0              0
# 331            -999              2            -999           0              0
#
#      ... 6Z10_intenergy1  6Z10_inttype2 6Z10_intenergy2  6RNK_state  \
# 0    ...            -999              3            -999           0
# 1    ...            -999              3            -999           0
# 2    ...            -999              3            -999           0
# 3    ...            -999              3            -999           0
# 4    ...            -999              3            -999           0
# ..   ...             ...            ...             ...         ...
# 327  ...            -999              3            -999           0
# 328  ...            -999              3            -999           0
# 329  ...            -999              3            -999           0
# 330  ...            -999              3            -999           0
# 331  ...            -999              3            -999           0
#
#     6RNK_function  6RNK_intenergysum  6RNK_inttype1 6RNK_intenergy1  \
# 0               0               -999              2            -999
# 1               0               -999              2            -999
# 2               0               -999              2            -999
# 3               0               -999              2            -999
# 4               0               -999              2            -999
# ..            ...                ...            ...             ...
# 327             0               -999              2            -999
# 328             0               -999              2            -999
# 329             0               -999              2            -999
# 330             0               -999              2            -999
# 331             0               -999              2            -999
#
#      6RNK_inttype2 6RNK_intenergy2
# 0                3            -999
# 1                3            -999
# 2                3            -999
# 3                3            -999
# 4                3            -999
# ..             ...             ...
# 327              3            -999
# 328              3            -999
# 329              3            -999
# 330              3            -999
# 331              3            -999
#
# [332 rows x 2549 columns]

# %%
ml_df.to_csv('ml_df_test.csv')

# %% [markdown]
# ---
# # Machine Learning

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# X has features, y has residues
X = ml_df.drop(['residue'], axis = 1)
y = ml_df['residue']

# %%
# scale data
scaler = StandardScaler()
to_scale = [col for col in X.columns.values]
scaler.fit(X[to_scale])
X[to_scale] = scaler.transform(X[to_scale])

# predict z-scores on the test set
X[to_scale] = scaler.transform(X[to_scale])

# %%
# display scaled values
display(X)
# Out:
#      7EW2_state  7EW2_function  7EW2_intenergysum  7EW2_inttype1  \
# 0           0.0            0.0           9.077976     -13.612786
# 1           0.0            0.0           9.077976     -13.612786
# 2           0.0            0.0           9.077976     -13.612786
# 3           0.0            0.0           9.077976     -13.612786
# 4           0.0            0.0           9.077976     -13.612786
# ..          ...            ...                ...            ...
# 327         0.0            0.0           9.077976     -13.612786
# 328         0.0            0.0           9.077976     -13.612786
# 329         0.0            0.0           9.077976     -13.612786
# 330         0.0            0.0           9.077976     -13.612786
# 331         0.0            0.0           9.077976     -13.612786
#
#      7EW2_intenergy1  7EW2_inttype2  7EW2_intenergy2  7EW3_state  \
# 0           9.060944     -15.664495        12.892326         0.0
# 1           9.060944     -15.664495        12.892326         0.0
# 2           9.060944     -15.664495        12.892326         0.0
# 3           9.060944     -15.664495        12.892326         0.0
# 4           9.060944     -15.664495        12.892326         0.0
# ..               ...            ...              ...         ...
# 327         9.060944     -15.664495        12.892326         0.0
# 328         9.060944     -15.664495        12.892326         0.0
# 329         9.060944     -15.664495        12.892326         0.0
# 330         9.060944     -15.664495        12.892326         0.0
# 331         9.060944     -15.664495        12.892326         0.0
#
#      7EW3_function  7EW3_intenergysum  ...  6Z10_intenergy1  6Z10_inttype2  \
# 0              0.0           9.076506  ...         7.386646     -10.959834
# 1              0.0           9.076506  ...         7.386646     -10.959834
# 2              0.0           9.076506  ...         7.386646     -10.959834
# 3              0.0           9.076506  ...         7.386646     -10.959834
# 4              0.0           9.076506  ...         7.386646     -10.959834
# ..             ...                ...  ...              ...            ...
# 327            0.0           9.076506  ...         7.386646     -10.959834
# 328            0.0           9.076506  ...         7.386646     -10.959834
# 329            0.0           9.076506  ...         7.386646     -10.959834
# 330            0.0           9.076506  ...         7.386646     -10.959834
# 331            0.0           9.076506  ...         7.386646     -10.959834
#
#      6Z10_intenergy2  6RNK_state  6RNK_function  6RNK_intenergysum  \
# 0           9.065415         0.0            0.0           5.701613
# 1           9.065415         0.0            0.0           5.701613
# 2           9.065415         0.0            0.0           5.701613
# 3           9.065415         0.0            0.0           5.701613
# 4           9.065415         0.0            0.0           5.701613
# ..               ...         ...            ...                ...
# 327         9.065415         0.0            0.0           5.701613
# 328         9.065415         0.0            0.0           5.701613
# 329         9.065415         0.0            0.0           5.701613
# 330         9.065415         0.0            0.0           5.701613
# 331         9.065415         0.0            0.0           5.701613
#
#      6RNK_inttype1  6RNK_intenergy1  6RNK_inttype2  6RNK_intenergy2
# 0        -8.298665         5.691266      -11.15604         8.089051
# 1        -8.298665         5.691266      -11.15604         8.089051
# 2        -8.298665         5.691266      -11.15604         8.089051
# 3        -8.298665         5.691266      -11.15604         8.089051
# 4        -8.298665         5.691266      -11.15604         8.089051
# ..             ...              ...            ...              ...
# 327      -8.298665         5.691266      -11.15604         8.089051
# 328      -8.298665         5.691266      -11.15604         8.089051
# 329      -8.298665         5.691266      -11.15604         8.089051
# 330      -8.298665         5.691266      -11.15604         8.089051
# 331      -8.298665         5.691266      -11.15604         8.089051
#
# [332 rows x 2548 columns]

# %% [markdown]
# ### Mean Shift Clustering

# %%
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=332)

# %%
ms = MeanShift(bandwidth = bandwidth)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_
 
labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)
 
# Print the number of clusters in the data
print("Clusters found: %d" % n_clusters_)
# Out:
# Clusters found: 65

# %%
ml_df['cluster_labels'] = labels

# %%
ml_df.to_csv('ml_df_meanshift_clustering_results.csv')

# %%
ml_df.loc[ml_df['cluster_labels'] == 9]
# Out:
#    residue 7EW2_intenergysum  7EW2_inttype1 7EW2_intenergy1  7EW2_inttype2  \
# 87    3.29         -6.744811              2       -0.930633              1
#
#    7EW2_intenergy2 7EW3_intenergysum  7EW3_inttype1 7EW3_intenergy1  \
# 87       -5.814178          -8.58787              0            -0.1
#
#     7EW3_inttype2  ... 6Z10_inttype1 6Z10_intenergy1  6Z10_inttype2  \
# 87              0  ...             1            -0.5              1
#
#    6Z10_intenergy2  6RNK_intenergysum 6RNK_inttype1 6RNK_intenergy1  \
# 87            -0.1               -0.7             1            -0.4
#
#     6RNK_inttype2 6RNK_intenergy2  cluster_labels
# 87              1            -0.2               9
#
# [1 rows x 1822 columns]

# %% [markdown]
# ### K Means Clustering

# %%
from sklearn.cluster import KMeans
rng = 1

# %%
clustering = KMeans(n_clusters=2, random_state=rng)
clustering.fit(X)
labels = clustering.labels_
ml_df['cluster_labels'] = labels

# %%
ml_df.to_csv('ml_df_kmeans_clustering_results.csv')

# %%
ml_df.loc[ml_df['cluster_labels'] == 0]
# Out:
#     residue  7EW2_state  7EW2_function 7EW2_intenergysum  7EW2_inttype1  \
# 0      1.21           0              0              -999              3
# 1      1.22           0              0              -999              3
# 2      1.23           0              0              -999              3
# 3      1.24           0              0              -999              3
# 4      1.25           0              0              -999              3
# ..      ...         ...            ...               ...            ...
# 327    7.64           0              0              -999              3
# 328    7.65           0              0              -999              3
# 329    7.66           0              0              -999              3
# 330    7.67           0              0              -999              3
# 331    7.68           0              0              -999              3
#
#     7EW2_intenergy1  7EW2_inttype2 7EW2_intenergy2  7EW3_state  7EW3_function  \
# 0              -999              2            -999           0              0
# 1              -999              2            -999           0              0
# 2              -999              2            -999           0              0
# 3              -999              2            -999           0              0
# 4              -999              2            -999           0              0
# ..              ...            ...             ...         ...            ...
# 327            -999              2            -999           0              0
# 328            -999              2            -999           0              0
# 329            -999              2            -999           0              0
# 330            -999              2            -999           0              0
# 331            -999              2            -999           0              0
#
#      ... 6Z10_inttype2  6Z10_intenergy2 6RNK_state  6RNK_function  \
# 0    ...             3             -999          0              0
# 1    ...             3             -999          0              0
# 2    ...             3             -999          0              0
# 3    ...             3             -999          0              0
# 4    ...             3             -999          0              0
# ..   ...           ...              ...        ...            ...
# 327  ...             3             -999          0              0
# 328  ...             3             -999          0              0
# 329  ...             3             -999          0              0
# 330  ...             3             -999          0              0
# 331  ...             3             -999          0              0
#
#     6RNK_intenergysum  6RNK_inttype1  6RNK_intenergy1 6RNK_inttype2  \
# 0                -999              2             -999             3
# 1                -999              2             -999             3
# 2                -999              2             -999             3
# 3                -999              2             -999             3
# 4                -999              2             -999             3
# ..                ...            ...              ...           ...
# 327              -999              2             -999             3
# 328              -999              2             -999             3
# 329              -999              2             -999             3
# 330              -999              2             -999             3
# 331              -999              2             -999             3
#
#      6RNK_intenergy2 cluster_labels
# 0               -999              0
# 1               -999              0
# 2               -999              0
# 3               -999              0
# 4               -999              0
# ..               ...            ...
# 327             -999              0
# 328             -999              0
# 329             -999              0
# 330             -999              0
# 331             -999              0
#
# [331 rows x 2550 columns]

# %%
ml_df = ml_df.drop(['cluster_labels'], axis = 1, inplace = True)

# %% [markdown]
# ### Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
labels = cluster.fit_predict(X)
ml_df['cluster_labels'] = labels

# %%
ml_df.to_csv('ml_df_agglomerative_clustering_results.csv')

# %%
ml_df.loc[ml_df['cluster_labels'] == 1]
# Out:
#     residue  7EW2_state  7EW2_function 7EW2_intenergysum  7EW2_inttype1  \
# 90     3.32           0              0            -999.0              3
# 91     3.33           0              0              -0.1              0
# 266    6.51           0              0            -999.0              3
# 270    6.55           0              0            -999.0              3
# 302    7.39           0              0            -999.0              3
#
#     7EW2_intenergy1  7EW2_inttype2 7EW2_intenergy2  7EW3_state  7EW3_function  \
# 90           -999.0              2          -999.0           0              0
# 91             -0.1              2          -999.0           0              0
# 266          -999.0              2          -999.0           0              0
# 270          -999.0              2          -999.0           0              0
# 302          -999.0              2          -999.0           0              0
#
#      ... 6Z10_inttype2  6Z10_intenergy2 6RNK_state  6RNK_function  \
# 90   ...             0             -0.3          0              0
# 91   ...             3           -999.0          0              0
# 266  ...             3           -999.0          0              0
# 270  ...             3           -999.0          0              0
# 302  ...             2        -4.114871          0              0
#
#     6RNK_intenergysum  6RNK_inttype1  6RNK_intenergy1 6RNK_inttype2  \
# 90               -0.4              1             -0.1             0
# 91             -999.0              2           -999.0             3
# 266              -0.2              0             -0.2             3
# 270            -999.0              2           -999.0             3
# 302        -12.189508              1             -4.0             2
#
#      6RNK_intenergy2 cluster_labels
# 90              -0.3              1
# 91            -999.0              1
# 266           -999.0              1
# 270           -999.0              1
# 302        -0.549586              1
#
# [5 rows x 2550 columns]

# %% [markdown]
# ### Gaussian Mixture Model

# %%
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=2)
labels = gmm.fit_predict(X)

# %%
ml_df['cluster_labels'] = labels

# %%
ml_df.loc[ml_df['cluster_labels'] == 0]
# Out:
#     residue  7EW2_state  7EW2_function 7EW2_intenergysum  7EW2_inttype1  \
# 90     3.32           0              0            -999.0              3
# 91     3.33           0              0              -0.1              0
# 266    6.51           0              0            -999.0              3
# 270    6.55           0              0            -999.0              3
# 302    7.39           0              0            -999.0              3
#
#     7EW2_intenergy1  7EW2_inttype2 7EW2_intenergy2  7EW3_state  7EW3_function  \
# 90           -999.0              2          -999.0           0              0
# 91             -0.1              2          -999.0           0              0
# 266          -999.0              2          -999.0           0              0
# 270          -999.0              2          -999.0           0              0
# 302          -999.0              2          -999.0           0              0
#
#      ... 6Z10_inttype2  6Z10_intenergy2 6RNK_state  6RNK_function  \
# 90   ...             0             -0.3          0              0
# 91   ...             3           -999.0          0              0
# 266  ...             3           -999.0          0              0
# 270  ...             3           -999.0          0              0
# 302  ...             2        -4.114871          0              0
#
#     6RNK_intenergysum  6RNK_inttype1  6RNK_intenergy1 6RNK_inttype2  \
# 90               -0.4              1             -0.1             0
# 91             -999.0              2           -999.0             3
# 266              -0.2              0             -0.2             3
# 270            -999.0              2           -999.0             3
# 302        -12.189508              1             -4.0             2
#
#      6RNK_intenergy2 cluster_labels
# 90              -0.3              0
# 91            -999.0              0
# 266           -999.0              0
# 270           -999.0              0
# 302        -0.549586              0
#
# [5 rows x 2550 columns]

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

#plotly imports
import plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

plotX = X.copy()

#PCA with two principal components
pca_2d = PCA(n_components=2)

clusters = ml_df['cluster_labels']
PCs_2d = pd.DataFrame(pca_2d.fit_transform(plotX))
PCs_2d.columns = ["PC1_2d", "PC2_2d"]
plotX['clusters'] = clusters
plotX['PC1_2d'] = PCs_2d['PC1_2d']
plotX['PC2_2d'] = PCs_2d['PC2_2d']

uniq_clusters = plotX['clusters'].unique()
uniqs = uniq_clusters.tolist()
uniqs.sort()

cluster0 = plotX[plotX['clusters'] == 0]
cluster1 = plotX[plotX['clusters'] == 1]

#trace1 is for 'Cluster 0'
trace1 = go.Scatter(
                    x = cluster0["PC1_2d"],
                    y = cluster0["PC2_2d"],
                    mode = "markers",
                    name = "Cluster I",
                    marker = dict(color = 'rgba(228,26,28,0.8)', size = 10, line=dict(width=1,color='Black')),
                    text = None)

#trace2 is for 'Cluster 1'
trace2 = go.Scatter(
                    x = cluster1["PC1_2d"],
                    y = cluster1["PC2_2d"],
                    mode = "markers",
                    name = "Cluster II",
                    marker = dict(color = 'rgba(43, 89, 39, 0.98)', size = 10, line=dict(width=1,color='Black')),
                    text = None)

data = [trace1, trace2]

layout = dict(xaxis= dict(title= 'PC1',dtick= 200,zeroline= False),
              yaxis= dict(title= 'PC2',ticklen= 5,zeroline= False),
              font_family="Arial",
              font = dict(size=16),
              width=800,
              height=800
             )

fig = dict(data = data, layout = layout)

iplot(fig)
# Out:
# <div>                            <div id="d37022fa-e8a9-4609-8c41-4cb8a9b3c2a3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d37022fa-e8a9-4609-8c41-4cb8a9b3c2a3")) {                    Plotly.newPlot(                        "d37022fa-e8a9-4609-8c41-4cb8a9b3c2a3",                        [{"marker":{"color":"rgba(228,26,28,0.8)","line":{"color":"Black","width":1},"size":10},"mode":"markers","name":"Cluster I","x":[-15.852944129015714,-15.852944129015773,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-14.583057474387367,-15.85294412901577,-15.85294412901577,-13.864060559421064,-12.217381431517385,-15.85294412901577,-15.85294412901577,-14.811862082340479,-8.02453418451045,-15.75913142244476,-15.85294412901577,-14.556248156054474,-7.718672422330369,-15.85294412901577,-15.85294412901577,-10.457527157593438,-15.516986965341271,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-16.62156466380568,-15.85294412901577,-16.809930669840096,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.990490983068948,-15.85294412901577,-15.85294412901577,-16.809930670017856,-15.85294412901577,-14.56693822676971,-15.85294412901577,-15.85294412901577,-9.23071578330581,-15.311095976955533,-15.85294412901577,-10.167928904193193,-1.608784383154493,-14.380824652199529,-15.520408782040569,86.5412102262904,21.263072618938722,-14.94544454145012,11.131775026800563,23.75417966352967,-6.476022103794198,-15.330224584182265,-16.77249612415605,-14.62741617581635,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.105480419677884,-15.85294412901577,-16.23049013803258,-16.230490138487543,-12.55830263794099,-15.365857413948516,-15.85294412901577,42.94007786361248,264.50137022565116,-14.07351671039808,-15.85294412901577,-15.537711681974358,-13.42046713401282,166.77462109197486,8.559067336054673,-15.85294412901577,-15.611547853256516,-14.78705682735522,-16.044080883019447,-15.85294412901577,-15.85294412901577,-16.426178509688768,-16.044080883019447,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.930935498351152,-16.68937504449384,-16.056912960497215,-15.85294412901577,-15.85294412901577,-23.100429010644234,-15.85294412901577,-15.661307118297064,-15.85294412901577,-14.791694447158703,-15.85294412901577,-12.928489617368061,-8.299180511292231,-13.730448657791372,-15.85294412901577,16.766711679134907,-15.601668003337927,-15.85294412901577,-15.85294412901577,-15.269517810488582,-15.85294412901577,-15.287561998133956,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.85294412901577,-15.265512309850646,-15.85294412901577,-15.85294412901577,-15.8 ...

# %%
plotX.loc[plotX['clusters'] == 1]
# Out:
#      7EW2_state  7EW2_function  7EW2_intenergysum  7EW2_inttype1  \
# 90          0.0            0.0           9.077976     -13.612786
# 91          0.0            0.0           9.162497     -80.672612
# 266         0.0            0.0           9.077976     -13.612786
# 270         0.0            0.0           9.077976     -13.612786
# 302         0.0            0.0           9.077976     -13.612786
#
#      7EW2_intenergy1  7EW2_inttype2  7EW2_intenergy2  7EW3_state  \
# 90          9.060944     -15.664495        12.892326         0.0
# 91          9.145153     -15.664495        12.892326         0.0
# 266         9.060944     -15.664495        12.892326         0.0
# 270         9.060944     -15.664495        12.892326         0.0
# 302         9.060944     -15.664495        12.892326         0.0
#
#      7EW3_function  7EW3_intenergysum  ...  6RNK_state  6RNK_function  \
# 90             0.0           9.076506  ...         0.0            0.0
# 91             0.0           9.076506  ...         0.0            0.0
# 266            0.0           9.076506  ...         0.0            0.0
# 270            0.0           9.076506  ...         0.0            0.0
# 302            0.0           9.076506  ...         0.0            0.0
#
#      6RNK_intenergysum  6RNK_inttype1  6RNK_intenergy1  6RNK_inttype2  \
# 90            5.736195     -29.626838         5.725737     -57.057206
# 91            5.701613      -8.298665         5.691266     -11.156040
# 266           5.736202     -50.955012         5.725733     -11.156040
# 270           5.701613      -8.298665         5.691266     -11.156040
# 302           5.735787     -29.626838         5.725602     -26.456429
#
#      6RNK_intenergy2  clusters      PC1_2d      PC2_2d
# 90          8.156564         1  838.920181 -592.641776
# 91          8.089051         1  615.374570 -335.234895
# 266         8.089051         1  759.779048  772.894336
# 270         8.089051         1  364.548023  239.243019
# 302         8.156547         1  535.703877 -151.055830
#
# [5 rows x 2551 columns]

# %%
PCs_2d
# Out:
#         PC1_2d    PC2_2d
# 0   -15.852944 -1.255547
# 1   -15.852944 -1.255547
# 2   -15.852944 -1.255547
# 3   -15.852944 -1.255547
# 4   -15.852944 -1.255547
# ..         ...       ...
# 327 -15.852944 -1.255547
# 328 -15.852944 -1.255547
# 329 -15.852944 -1.255547
# 330 -15.852944 -1.255547
# 331 -15.852944 -1.255547
#
# [332 rows x 2 columns]
